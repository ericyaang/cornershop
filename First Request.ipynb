# %%
import requests

# %%
# nome do produto
query='amaciante'
# cep
cep = 88010560
# país
country = 'BR'
# link
URL = f'https://cornershopapp.com/api/v2/branches/search?query={query}&locality={cep}&country={country}'
# aquisição da busca
json_file = requests.get(URL).json()

# exstraindo o objeto 'results' do conjunto
#results = json_file.get('results', [])
#print(f"Foram encontrados {len(results)} locais.")

# %%
json_file.keys()
# Out:
# dict_keys(['results', 'next'])

# %%
len(json_file['results'])
# Out:
# 8

# %% [markdown]
# - 'next' não tem nada
# - results é o objeto que contém todas as informações que precisamos. Ele retornou 8 objetos

# %% [markdown]
# Vamos extrair o que interessa

# %%
# extraindo o objeto 'results' do conjunto inincial
results = json_file.get('results', [])

# %%
# ver o primeiro objeto
results[0]
# Out:
# {'store': {'id': 1327,
#   'name': 'Carrefour Hiper',
#   'country': 'BR',
#   'locale': 'pt_BR',
#   'img_url': 'https://s.cornershopapp.com/store-logo/logo.png?versionId=0hQoZLynYGOG8J49xyESWLI9wPyTSNpR',
#   'light_img_url': 'https://s.cornershopapp.com/store-logo/logo.png?versionId=sf6ZKODyd0mote.Pt9MT4GzChqv.GA5j',
#   'self_picking': False,
#   'self_delivery': False,
#   'minimum_amount': 0.0,
#   'maximum_amount': None,
#   'closest_branch': {'id': 47560,
#    'lat': -27.589733,
#    'lng': -48.51528,
#    'picking_point': {'type': 'Point', 'coordinates': [-48.51528, -27.589733]},
#    'name': 'Villa Romana Shopping - Florianópolis',
#    'description': 'Tudo o que você precisa para cuidar da sua casa e da sua família, de forma rápida, prática e principalmente com os melhores preços.',
#    'description_disclaimer': None,
#    'store_id': 1327,
#    'store_name': 'Carrefour Hiper',
#    'store_img_url': 'https://s.cornershopapp.com/store-logo/logo.png?versionId=0hQoZLynYGOG8J49xyESWLI9wPyTSNpR',
#    'store_light_img_url': 'https://s.cornershopapp.com/store-logo/logo.png?versionId=sf6ZKODyd0mote.Pt9MT4GzChqv.GA5j',
#    'store_brand_color': '171796',
#    'locale': 'pt_BR',
#    'timezone': 'America/Sao_Paulo',
#    'address': 'Av. Me. Benvenuta, 687 - Loja 11 - Santa Monica , , , 88035-000',
#    'city': 'FLN',
#    'country': 'BR',
#    'is_partner': True,
#    'has_same_prices': True,
#    'pricing_notes': {'description': 'Os preços dos produtos são publicados pela loja Carrefour Hiper. A Cornershop cobra uma taxa de serviço que você poderá ver antes de efetuar o pagamento em "Taxa de serviço".',
#     'disclaimer_message': 'Os preços dos produtos são publicados pela loja Carrefour Hiper. A Cornershop cobra uma taxa de serviço que você poderá ver antes de efetuar o pagamento em "Taxa de serviço".',
#     'disclaimer_title': '3% taxa de serviço'},
#    'membership_notes': None,
#    'minimum_amount': 0,
#    'maximum_amount': None,
#    'weekly_schedule': [],
#    'covers_expenses': False,
#    'featured': [],
#    'poster': {'color': None,
#     'image': {'1x': 'https://s.cornershopapp.com/store-poster/1327-carrefour-hiper-1x.jpeg?versionId=LEjZC.ILWSx9j6PHzaLVWKvrqy3FoZP.',
#      '2x': 'https://s.cornershopapp.com/store-poster/1327-carrefour-hiper-2x.jpeg?versionId=91k.xJGqMyK4R7Y97WJnXk4HS5e_aUlC',
#      '3x': 'https://s.cornershopapp.com/store-poster/1327-carrefour-hiper-3x.jpeg?versionId=3_eRE0a.M2DYLjUv8C14ZTbNCRq8tobX'}},
#    'excerpt': 'Supermercado sem sair de casa',
#    'next_available_delivery': None,
#    'total_matches': 67},
#   'is_published': True,
#   'description': 'Tudo o que você precisa para cuidar da sua casa e da sua família, de forma rápida, prática e principalmente com os melhores preços.',
#   'description_disclaimer': ''},
#  'search_result': {'search_term': 'amaciante',
#   'aisles': [{'aisle_id': 'C_1582',
#     'aisle_name': 'Amaciantes',
#     'department_id': 'C_983',
#     'products': [{'id': 1191812,
#       'brand': {'id': 73710, 'name': 'Ypê'},
#       'kind': 'PRODUCT',
#       'related_to': None,
#       'buy_unit': 'UN',
#       'default_buy_unit': 'UN',
#       'variable_weight': None,
#       'currency': 'BRL',
#       'unit_conversion_rate': None,
#       'is_tobacco': False,
#       'purchasable': True,
#       'pricing': {'original_price': {'label': 'ORIGINAL_PRICE',
#         'amount': 12.19,
#         'currency': 'BRL'},
#        'price': {'label': 'Preço', 'amount': 9.75, 'currency': 'BRL'},
#        'price_per_unit': None},
#       'price_per_unit': '',
#       'regulatory_fees': [],
#       'price': 9.75,
#       'original_price': '12.19',
#       'label': '20 % OFF',
#       'description_sections': [{'title': 'Amaciantes com 20% de desconto',
#         'text': 'Receba 20% de desconto em produtos marcados com a promoção. Verifique termos e condições.',
#         'type': 'DISCOUNT'}],
#       'availability_status': 'AVAILABLE',
#       'nutritional_info': None,
#       'name': 'Amaciante de roupas intenso',
#       'description': 'O Amaciante Ypê está com uma nova fórmula. Tem mais perfume e o toque mágico com Hidraceramidas, para roupas mais perfumadas e macias.',
#       'package': '2l',
#       'img_url': 'https://s.cornershopapp.com/product-images/1191812.png?versionId=07SCwy3Zm8h04uvoiIyqBZPApRhLepPT',
#       'extra_img_urls': []},
#      {'id': 1265631,
#       'brand': {'id': 73710, 'name': 'Ypê'},
#       'kind': 'PRODUCT',
#       'related_to': None,
#       'buy_unit': 'UN',
#       'default_buy_unit': 'UN',
#       'variable_weight': None,
#       'currency': 'BRL',
#       'unit_conversion_rate': None,
#       'is_tobacco': False,
#       'purchasable': True,
#       'pricing': {'original_price': {'label': 'ORIGINAL_PRICE',
#         'amount': 12.19,
#         'currency': 'BRL'},
#        'price': {'label': 'Preço', 'amount': 9.75, 'currency': 'BRL'},
#        'price_per_unit': None},
#       'price_per_unit': '',
#       'regulatory_fees': [],
#       'price': 9.75,
#       'original_price': '12.19',
#       'label': '20 % OFF',
#       'description_sections': [{'title': 'Amaciantes com 20% de desconto',
#         'text': 'Receba 20% de desconto em produtos marcados com a promoção. Verifique termos e condições.',
#         'type': 'DISCOUNT'}],
#       'availability_status': 'AVAILABLE',
#       'nutritional_info': None,
#       'name': 'Amaciante de roupas Aconchego',
#       'description': '',
#       'package': '2l',
#       'img_url': 'https://s.cornershopapp.com/product-images/1265631.png?versionId=c2eMNDfLXKs5ENLq1J8op8ftAxnRD0VH',
#       'extra_img_urls': []},
#      {'id': 1191769,
#       'brand': {'id': 659, 'name': 'Downy'},
#       'kind': 'PRODUCT',
#       'related_to': None,
#       'buy_unit': 'UN',
#       'default_buy_unit': 'UN',
#       'variable_weight': False,
#       'currency': 'BRL',
#       'unit_conversion_rate': None,
#       'is_tobacco': False,
#       'purchasable': True,
#       'pricing': {'original_price': None,
#        'price': {'label': 'Preço', 'amount': 25.59, 'currency': 'BRL'},
#        'price_per_unit': None},
#       'price_per_unit': '',
#       'regulatory_fees': [],
#       'price': 25.59,
#       'original_price': None,
#       'label': 'Ver Promo',
#       'description_sections': [{'title': 'Ofertas Especiais com entrega grátis',
#         'text': 'Comprando R$280 em produtos Ofertas Especiais marcados com a promoção, você não paga a entrega.',
#         'type': 'DELIVERY'}],
#       'availability_status': 'AVAILABLE',
#       'nutritional_info': None,
#       'name': 'Amaciante de roupas concentrado Brisa de Verão',
#       'description': 'Amaciante concentrado que deixa as suas roupas perfumadas por mais tempo*! Downy Brisa resultadas da combinação de flores brancas e cítricas e do frescor do herbal e âmbar. A fórmula de Downy possui microcápsulas de perfume especiais que se ativam com o toque, liberando perfume ao longo de todo o dia. Além disso, protege de odores desagradáveis como fumaça, fritura e suor, os impedindo de impregnar nas roupas**. Desta forma você se veste de perfume o dia todo. Por ser concentrado, 1.5L de Downy é equivalente a 6L de um amaciante diluído comum. Isso significa que ele rende até 66 lavagens. Para garantir um melhor uso, utilize apenas a quantidade de amaciante indicada na embalagem do produto. *Concentração de perfume depositada e liberada do tecido seco medida por métodos analíticos vs. amaciantes não concentrados **Baseado em provas realizadas com conjunto de odores representativos',
#       'package': '1l',
#       'img_url': 'https://s.cornershopapp.com/product-images/1191769.jpg?versionId=Hb1SFC8lD.f5cWUUwR.B.1LRVYDXepa9',
#       'extra_img_urls': []},
#      {'id': 1191770,
#       'brand': {'id': 659, 'name': 'Downy'},
#       'kind': 'PRODUCT',
#       'related_to': None,
#       'buy_unit': 'UN',
#       'default_buy_unit': 'UN',
#       'variable_weight': None,
#       'currency': 'BRL',
#       'unit_conversion_rate': None,
#       'is_tobacco': False,
#       'purchasable': True,
#       'pricing': {'original_price': {'label': 'ORIGINAL_PRICE',
#         'amount': 33.99,
#         'currency': 'BRL'},
#        'price': {'label': 'Preço', 'amount': 25.65, 'currency': 'BRL'},
#        'price_per_unit': None},
#       'price_per_unit': '',
#       'regulatory_fees': [],
#       'price': 25.65,
#       'original_price': '33.99',
#       'label': 'Ver Promo',
#       'description_sections': [{'title': 'Ofertas Especiais com entrega grátis',
#         'text': 'Comprando R$280 em produtos Ofertas Especiais marcados com a promoção, você não paga a entrega.',
#         'type': 'DELIVERY'},
#        {'title': 'Promoção Carrefour Hiper',
#         'text': 'Desconto exclusivo Carrefour Hiper',
#         'type': 'DISCOUNT'}],
#       'availability_status': 'AVAILABLE',
#       'nutritional_info': None,
#       'name': 'Amaciante de roupas concentrado Brisa de Verão',
#       'description': 'Amaciante concentrado que deixa as suas roupas perfumadas por mais tempo*! Downy Brisa resultadas da combinação de flores brancas e cítricas e do frescor do herbal e âmbar. A fórmula de Downy possui microcápsulas de perfume especiais que se ativam com o toque, liberando perfume ao longo de todo o dia. Além disso, protege de odores desagradáveis como fumaça, fritura e suor, os impedindo de impregnar nas roupas**. Desta forma você se veste de perfume o dia todo. Por ser concentrado, 1.5L de Downy é equivalente a 6L de um amaciante diluído comum. Isso significa que ele rende até 66 lavagens. Para garantir um melhor uso, utilize apenas a quantidade de amaciante indicada na embalagem do produto. *Concentração de perfume depositada e liberada do tecido seco medida por métodos analíticos vs. amaciantes não concentrados **Baseado em provas realizadas com conjunto de odores representativos',
#       'package': '1,5l',
#       'img_url': 'https://s.cornershopapp.com/product-images/1191770.jpg?versionId=2.ZgxKwn9gbRHrkKRxB1PhXo65UGUykU',
#       'extra_img_urls': []},
#      {'id': 1258284,
#       'brand': {'id': 73710, 'name': 'Ypê'},
#       'kind': 'PRODUCT',
#       'related_to': None,
#       'buy_unit': 'UN',
#       'default_buy_unit': 'UN',
#       'variable_weight': False,
#       'currency': 'BRL',
#       'unit_conversion_rate': None,
#       'is_tobacco': False,
#       'purchasable': True,
#       'pricing': {'original_price': {'label': 'ORIGINAL_PRICE',
#         'amount': 24.99,
#         'currency': 'BRL'},
#        'price': {'label': 'Preço', 'amount': 19.99, 'currency': 'BRL'},
#        'price_per_unit': None},
#       'price_per_unit': '',
#       'regulatory_fees': [],
#       'price': 19.99,
#       'original_price': '24.99',
#       'label': '20 % OFF',
#       'description_sections': [{'title': 'Amaciantes com 20% de desconto',
#         'text': 'Receba 20% de desconto em produtos marcados com a promoção. Verifique termos e condições.',
#         'type': 'DISCOUNT'},
#        {'title': 'Ofertas Especiais com entrega grátis',
#         'text': 'Comprando R$280 em produtos Ofertas Especiais marcados com a promoção, você não paga a entrega.',
#         'type': 'DELIVERY'}],
#       'availability_status': 'AVAILABLE',
#       'nutritional_info': None,
#       'name': 'Amaciante de roupas Aconchego',
#       'description': 'Embalagem promocional leve 5l e pague 4,5l',
#       'package': '5l',
#       'img_url': 'https://s.cornershopapp.com/product-images/1258284.jpg?versionId=47fyTmBcsh9UuJJDly51ZPBa2Bzw5HKQ',
#       'extra_img_urls': []},
#      {'id': 1313371,
#       'brand': {'id': 66629, 'name': 'Comfort'},
#       'kind': 'PRODUCT',
#       'related_to': None,
#       'buy_unit': 'UN',
#       'default_buy_unit': 'UN',
#       'variable_weight': None,
#       'currency': 'BRL',
#       'unit_conversion_rate': None,
#       'is_tobacco': False,
#       'purchasable': True,
#       'pricing': {'original_price': None,
#        'price': {'label': 'Preço', 'amount': 31.69, 'currency': 'BRL'},
#        'price_per_unit': None},
#       'price_per_unit': '',
#       'regulatory_fees': [],
#       'price': 31.69,
#       'original_price': None,
#       'label': 'Ver Promo',
#       'description_sections': [{'title': 'Ofertas Especiais com entrega grátis',
#         'text': 'Comprando R$280 em produtos Ofertas Especiais marcados com a promoção, você não paga a entrega.',
#         'type': 'DELIVERY'}],
#       'availability_status': 'AVAILABLE',
#       'nutritional_info': None,
#       'name': 'Amaciante concentrado para roupas cuidado intensivo óleo de argan',
#       'description': 'Rende 6,7 litros.',
#       'package': '1,5l',
#       'img_url': 'https://s.cornershopapp.com/product-images/1313371.jpg?versionId=9dnSRos4ZWVdhw3.wLqDDNABBJGnvgen',
#       'extra_img_urls': []},
#      {'id': 1258221,
#       'brand': {'id': 66629, 'name': 'Comfort'},
#       'kind': 'PRODUCT',
#       'related_to': None,
#       'buy_unit': 'UN',
#       'default_buy_unit': 'UN',
#       'variable_weight': None,
#       'currency': 'BRL',
#       'unit_conversion_rate': None,
#       'is_tobacco': False,
#       'purchasable': True,
#       'pricing': {'original_price': None,
#        'price': {'label': 'Preço', 'amount': 21.89, 'currency': 'BRL'},
#        'price_per_unit': None},
#       'price_per_unit': '',
#       'regulatory_fees': [],
#       'price': 21.89,
#       'original_price': None,
#       'label': 'Ver Promo',
#       'description_sections': [{'title': 'Ofertas Especiais com entrega grátis',
#         'text': 'Comprando R$280 em produtos Ofertas Especiais marcados com a promoção, você não paga a entrega.',
#         'type': 'DELIVERY'}],
#       'availability_status': 'AVAILABLE',
#       'nutritional_info': None,
#       'name': 'Refil de amaciante de roupas concentrado Original',
#       'description': 'Refil amaciante de roupa concentrado original intensivo cuidado essencial Confort.',
#       'package': '900ml',
#       'img_url': 'https://s.cornershopapp.com/product-images/1258221.jpg?versionId=9O.dcr.VipUrv7QH5bOKAzB_soEFtx.r',
#       'extra_img_urls': []},
#      {'id': 1316764,
#       'brand': {'id': 66629, 'name': 'Comfort'},
#       'kind': 'PRODUCT',
#       'related_to': None,
#       'buy_unit': 'UN',
#       'default_buy_unit': 'UN',
#       'variable_weight': False,
#       'currency': 'BRL',
#       'unit_conversion_rate': None,
#       'is_tobacco': False,
#       'purchasable': True,
#       'pricing': {'original_price': None,
#        'price': {'label': 'Preço', 'amount': 21.89, 'currency': 'BRL'},
#        'price_per_unit': None},
#       'price_per_unit': '',
#       'regulatory_fees': [],
#       'price': 21.89,
#       'original_price': None,
#       'label': 'Ver Promo',
#       'description_sections': [{'title': 'Ofertas Especiais com entrega grátis',
#         'text': 'Comprando R$280 em produtos Ofertas Especiais marcados com a promoção, você não paga a entrega.',
#         'type': 'DELIVERY'}],
#       'availability_status': 'AVAILABLE',
#       'nutritional_info': None,
#       'name': 'Refil de amaciante de roupas concentrado hipoalergênico',
#       'description': '.',
#       'package': '900ml',
#       'img_url': 'https://s.cornershopapp.com/product-images/1316764.jpg?versionId=xIjYKT2_uC_mYfUvRwrgkFhupsjlxilP',
#       'extra_img_urls': []},
#      {'id': 1191776,
#       'brand': {'id': 659, 'name': 'Downy'},
#       'kind': 'PRODUCT',
#       'related_to': None,
#       'buy_unit': 'UN',
#       'default_buy_unit': 'UN',
#       'variable_weight': None,
#       'currency': 'BRL',
#       'unit_conversion_rate': None,
#       'is_tobacco': False,
#       'purchasable': True,
#       'pricing': {'original_price': None,
#        'price': {'label': 'Preço', 'amount': 13.19, 'currency': 'BRL'},
#        'price_per_unit': None},
#       'price_per_unit': '',
#       'regulatory_fees': [],
#       'price': 13.19,
#       'original_price': None,
#       'label': None,
#       'description_sections': [],
#       'availability_status': 'AVAILABLE',
#       'nutritional_info': None,
#       'name': 'Amaciante de roupas concentrado Lírios do Campo',
#       'description': 'Amaciante concentrado que deixa as suas roupas perfumadas por mais tempo*! Downy Lírios do Campo possuí notas de perfume de rosas com um toque de flor de laranjeira, resultando em uma fragrância levemente adocicada. A fórmula de Downy possui microcápsulas de perfume especiais que se ativam com o toque, liberando perfume ao longo de todo o dia. Além disso, protege de odores desagradáveis como fumaça, fritura e suor, os impedindo de impregnar nas roupas**. Desta forma você se veste de perfume o dia todo. Por ser concentrado, 1.5L de Downy é equivalente a 6L de um amaciante diluído comum. Isso significa que ele rende até 66 lavagens. Para garantir um melhor uso, utilize apenas a quantidade de amaciante indicada na embalagem do produto. *Concentração de perfume depositada e liberada do tecido seco medida por métodos analíticos vs. amaciantes não concentrados **Baseado em provas realizadas com conjunto de odores representativos',
#       'package': '500g',
#       'img_url': 'https://s.cornershopapp.com/product-images/1191776.jpg?versionId=q9xhPumySv98bDUDJjB2Z3ylRyTGx.mE',
#       'extra_img_urls': []},
#      {'id': 1315722,
#       'brand': {'id': 66629, 'name': 'Comfort'},
#       'kind': 'PRODUCT',
#       'related_to': None,
#       'buy_unit': 'UN',
#       'default_buy_unit': 'UN',
#       'variable_weight': False,
#       'currency': 'BRL',
#       'unit_conversion_rate': None,
#       'is_tobacco': False,
#       'purchasable': True,
#       'pricing': {'original_price': None,
#        'price': {'label': 'Preço', 'amount': 31.69, 'currency': 'BRL'},
#        'price_per_unit': None},
#       'price_per_unit': '',
#       'regulatory_fees': [],
#       'price': 31.69,
#       'original_price': None,
#       'label': 'Ver Promo',
#       'description_sections': [{'title': 'Ofertas Especiais com entrega grátis',
#         'text': 'Comprando R$280 em produtos Ofertas Especiais marcados com a promoção, você não paga a entrega.',
#         'type': 'DELIVERY'}],
#       'availability_status': 'AVAILABLE',
#       'nutritional_info': None,
#       'name': 'Amaciante de roupas concentrado Puro Cuidado',
#       'description': 'Amaciante de roupas concentrado Puro Cuidado hipoalergênico óleo de argan',
#       'package': 'Garrafa 1,5l',
#       'img_url': 'https://s.cornershopapp.com/product-images/1315722.jpg?versionId=BUpObFsRuI9y0_pjFH_k_wcz8SbuKzV3',
#       'extra_img_urls': []},
#      {'id': 1191787,
#       'brand': {'id': 66629, 'name': 'Comfort'},
#       'kind': 'PRODUCT',
#       'related_to': None,
#       'buy_unit': 'UN',
#       'default_buy_unit': 'UN',
#       'variable_weight': False,
#       'currency': 'BRL',
#       'unit_conversion_rate': None,
#       'is_tobacco': False,
#       'purchasable': True,
#       'pricing': {'original_price': None,
#        'price': {'label': 'Preço', 'amount': 22.99, 'currency': 'BRL'},
#        'price_per_unit': None},
#       'price_per_unit': '',
#       'regulatory_fees': [],
#       'price': 22.99,
#       'original_price': None,
#       'label': None,
#       'description_sections': [],
#       'availability_status': 'AVAILABLE',
#       'nutritional_info': None,
#       'name': 'Amaciante de roupas concentrado intense com óleo de argan',
#       'description': None,
#       'package': '1l',
#       'img_url': 'https://s.cornershopapp.com/product-images/1191787.jpg?versionId=naRBJ3eQ9K8IbLw2228va.F2DWDMFZ0U',
#       'extra_img_urls': []},
#      {'id': 1191778,
#       'brand': {'id': 66629, 'name': 'Comfort'},
#       'kind': 'PRODUCT',
#       'related_to': None,
#       'buy_unit': 'UN',
#       'default_buy_unit': 'UN',
#       'variable_weight': False,
#       'currency': 'BRL',
#       'unit_conversion_rate': None,
#       'is_tobacco': False,
#       'purchasable': True,
#       'pricing': {'original_price': None,
#        'price': {'label': 'Preço', 'amount': 22.99, 'currency': 'BRL'},
#        'price_per_unit': None},
#       'price_per_unit': '',
#       'regulatory_fees': [],
#       'price': 22.99,
#       'original_price': None,
#       'label': None,
#       'description_sections': [],
#       'availability_status': 'AVAILABLE',
#       'nutritional_info': None,
#       'name': 'Amaciante de roupa concentrado cuidado intensivo com óleo de argan',
#       'description': None,
#       'package': '1l',
#       'img_url': 'https://s.cornershopapp.com/product-images/1191778.jpg?versionId=CiEyR3vsf_e94dRrpVOgcvCAViKbct.U',
#       'extra_img_urls': []},
#      {'id': 1191782,
#       'brand': {'id': 66629, 'name': 'Comfort'},
#       'kind': 'PRODUCT',
#       'related_to': None,
#       'buy_unit': 'UN',
#       'default_buy_unit': 'UN',
#       'variable_weight': None,
#       'currency': 'BRL',
#       'unit_conversion_rate': None,
#       'is_tobacco': False,
#       'purchasable': True,
#       'pricing': {'original_price': None,
#        'price': {'label': 'Preço', 'amount': 22.99, 'currency': 'BRL'},
#        'price_per_unit': None},
#       'price_per_unit': '',
#       'regulatory_fees': [],
#       'price': 22.99,
#       'original_price': None,
#       'label': None,
#       'description_sections': [],
#       'availability_status': 'AVAILABLE',
#       'nutritional_info': None,
#       'name': 'Amaciante de roupa concentrado Glamour',
#       'description': 'Amaciante concentrado Comfort, extrema maciez com exclusivo perfume envolvente. Cuidadosamente desenvolvido para deixar os tecidos macios e fáceis de passar e com um delicioso perfume encantador e duradouro.',
#       'package': '1l',
#       'img_url': 'https://s.cornershopapp.com/product-images/1191782.jpg?versionId=bMiuU2nXMS5R5FJjvCTvXYOYelXZORA6',
#       'extra_img_urls': []}]}]}}

# %%
results[0].keys()
# Out:
# dict_keys(['store', 'search_result'])

# %%
results[0]['store']
# Out:
# {'id': 1327,
#  'name': 'Carrefour Hiper',
#  'country': 'BR',
#  'locale': 'pt_BR',
#  'img_url': 'https://s.cornershopapp.com/store-logo/logo.png?versionId=0hQoZLynYGOG8J49xyESWLI9wPyTSNpR',
#  'light_img_url': 'https://s.cornershopapp.com/store-logo/logo.png?versionId=sf6ZKODyd0mote.Pt9MT4GzChqv.GA5j',
#  'self_picking': False,
#  'self_delivery': False,
#  'minimum_amount': 0.0,
#  'maximum_amount': None,
#  'closest_branch': {'id': 47560,
#   'lat': -27.589733,
#   'lng': -48.51528,
#   'picking_point': {'type': 'Point', 'coordinates': [-48.51528, -27.589733]},
#   'name': 'Villa Romana Shopping - Florianópolis',
#   'description': 'Tudo o que você precisa para cuidar da sua casa e da sua família, de forma rápida, prática e principalmente com os melhores preços.',
#   'description_disclaimer': None,
#   'store_id': 1327,
#   'store_name': 'Carrefour Hiper',
#   'store_img_url': 'https://s.cornershopapp.com/store-logo/logo.png?versionId=0hQoZLynYGOG8J49xyESWLI9wPyTSNpR',
#   'store_light_img_url': 'https://s.cornershopapp.com/store-logo/logo.png?versionId=sf6ZKODyd0mote.Pt9MT4GzChqv.GA5j',
#   'store_brand_color': '171796',
#   'locale': 'pt_BR',
#   'timezone': 'America/Sao_Paulo',
#   'address': 'Av. Me. Benvenuta, 687 - Loja 11 - Santa Monica , , , 88035-000',
#   'city': 'FLN',
#   'country': 'BR',
#   'is_partner': True,
#   'has_same_prices': True,
#   'pricing_notes': {'description': 'Os preços dos produtos são publicados pela loja Carrefour Hiper. A Cornershop cobra uma taxa de serviço que você poderá ver antes de efetuar o pagamento em "Taxa de serviço".',
#    'disclaimer_message': 'Os preços dos produtos são publicados pela loja Carrefour Hiper. A Cornershop cobra uma taxa de serviço que você poderá ver antes de efetuar o pagamento em "Taxa de serviço".',
#    'disclaimer_title': '3% taxa de serviço'},
#   'membership_notes': None,
#   'minimum_amount': 0,
#   'maximum_amount': None,
#   'weekly_schedule': [],
#   'covers_expenses': False,
#   'featured': [],
#   'poster': {'color': None,
#    'image': {'1x': 'https://s.cornershopapp.com/store-poster/1327-carrefour-hiper-1x.jpeg?versionId=LEjZC.ILWSx9j6PHzaLVWKvrqy3FoZP.',
#     '2x': 'https://s.cornershopapp.com/store-poster/1327-carrefour-hiper-2x.jpeg?versionId=91k.xJGqMyK4R7Y97WJnXk4HS5e_aUlC',
#     '3x': 'https://s.cornershopapp.com/store-poster/1327-carrefour-hiper-3x.jpeg?versionId=3_eRE0a.M2DYLjUv8C14ZTbNCRq8tobX'}},
#   'excerpt': 'Supermercado sem sair de casa',
#   'next_available_delivery': None,
#   'total_matches': 67},
#  'is_published': True,
#  'description': 'Tudo o que você precisa para cuidar da sua casa e da sua família, de forma rápida, prática e principalmente com os melhores preços.',
#  'description_disclaimer': ''}

# %% [markdown]
# O objeto `store` contém informações sobre a loja

# %%
results[0]['search_result']
# Out:
# {'search_term': 'amaciante',
#  'aisles': [{'aisle_id': 'C_1582',
#    'aisle_name': 'Amaciantes',
#    'department_id': 'C_983',
#    'products': [{'id': 1191812,
#      'brand': {'id': 73710, 'name': 'Ypê'},
#      'kind': 'PRODUCT',
#      'related_to': None,
#      'buy_unit': 'UN',
#      'default_buy_unit': 'UN',
#      'variable_weight': None,
#      'currency': 'BRL',
#      'unit_conversion_rate': None,
#      'is_tobacco': False,
#      'purchasable': True,
#      'pricing': {'original_price': {'label': 'ORIGINAL_PRICE',
#        'amount': 12.19,
#        'currency': 'BRL'},
#       'price': {'label': 'Preço', 'amount': 9.75, 'currency': 'BRL'},
#       'price_per_unit': None},
#      'price_per_unit': '',
#      'regulatory_fees': [],
#      'price': 9.75,
#      'original_price': '12.19',
#      'label': '20 % OFF',
#      'description_sections': [{'title': 'Amaciantes com 20% de desconto',
#        'text': 'Receba 20% de desconto em produtos marcados com a promoção. Verifique termos e condições.',
#        'type': 'DISCOUNT'}],
#      'availability_status': 'AVAILABLE',
#      'nutritional_info': None,
#      'name': 'Amaciante de roupas intenso',
#      'description': 'O Amaciante Ypê está com uma nova fórmula. Tem mais perfume e o toque mágico com Hidraceramidas, para roupas mais perfumadas e macias.',
#      'package': '2l',
#      'img_url': 'https://s.cornershopapp.com/product-images/1191812.png?versionId=07SCwy3Zm8h04uvoiIyqBZPApRhLepPT',
#      'extra_img_urls': []},
#     {'id': 1265631,
#      'brand': {'id': 73710, 'name': 'Ypê'},
#      'kind': 'PRODUCT',
#      'related_to': None,
#      'buy_unit': 'UN',
#      'default_buy_unit': 'UN',
#      'variable_weight': None,
#      'currency': 'BRL',
#      'unit_conversion_rate': None,
#      'is_tobacco': False,
#      'purchasable': True,
#      'pricing': {'original_price': {'label': 'ORIGINAL_PRICE',
#        'amount': 12.19,
#        'currency': 'BRL'},
#       'price': {'label': 'Preço', 'amount': 9.75, 'currency': 'BRL'},
#       'price_per_unit': None},
#      'price_per_unit': '',
#      'regulatory_fees': [],
#      'price': 9.75,
#      'original_price': '12.19',
#      'label': '20 % OFF',
#      'description_sections': [{'title': 'Amaciantes com 20% de desconto',
#        'text': 'Receba 20% de desconto em produtos marcados com a promoção. Verifique termos e condições.',
#        'type': 'DISCOUNT'}],
#      'availability_status': 'AVAILABLE',
#      'nutritional_info': None,
#      'name': 'Amaciante de roupas Aconchego',
#      'description': '',
#      'package': '2l',
#      'img_url': 'https://s.cornershopapp.com/product-images/1265631.png?versionId=c2eMNDfLXKs5ENLq1J8op8ftAxnRD0VH',
#      'extra_img_urls': []},
#     {'id': 1191769,
#      'brand': {'id': 659, 'name': 'Downy'},
#      'kind': 'PRODUCT',
#      'related_to': None,
#      'buy_unit': 'UN',
#      'default_buy_unit': 'UN',
#      'variable_weight': False,
#      'currency': 'BRL',
#      'unit_conversion_rate': None,
#      'is_tobacco': False,
#      'purchasable': True,
#      'pricing': {'original_price': None,
#       'price': {'label': 'Preço', 'amount': 25.59, 'currency': 'BRL'},
#       'price_per_unit': None},
#      'price_per_unit': '',
#      'regulatory_fees': [],
#      'price': 25.59,
#      'original_price': None,
#      'label': 'Ver Promo',
#      'description_sections': [{'title': 'Ofertas Especiais com entrega grátis',
#        'text': 'Comprando R$280 em produtos Ofertas Especiais marcados com a promoção, você não paga a entrega.',
#        'type': 'DELIVERY'}],
#      'availability_status': 'AVAILABLE',
#      'nutritional_info': None,
#      'name': 'Amaciante de roupas concentrado Brisa de Verão',
#      'description': 'Amaciante concentrado que deixa as suas roupas perfumadas por mais tempo*! Downy Brisa resultadas da combinação de flores brancas e cítricas e do frescor do herbal e âmbar. A fórmula de Downy possui microcápsulas de perfume especiais que se ativam com o toque, liberando perfume ao longo de todo o dia. Além disso, protege de odores desagradáveis como fumaça, fritura e suor, os impedindo de impregnar nas roupas**. Desta forma você se veste de perfume o dia todo. Por ser concentrado, 1.5L de Downy é equivalente a 6L de um amaciante diluído comum. Isso significa que ele rende até 66 lavagens. Para garantir um melhor uso, utilize apenas a quantidade de amaciante indicada na embalagem do produto. *Concentração de perfume depositada e liberada do tecido seco medida por métodos analíticos vs. amaciantes não concentrados **Baseado em provas realizadas com conjunto de odores representativos',
#      'package': '1l',
#      'img_url': 'https://s.cornershopapp.com/product-images/1191769.jpg?versionId=Hb1SFC8lD.f5cWUUwR.B.1LRVYDXepa9',
#      'extra_img_urls': []},
#     {'id': 1191770,
#      'brand': {'id': 659, 'name': 'Downy'},
#      'kind': 'PRODUCT',
#      'related_to': None,
#      'buy_unit': 'UN',
#      'default_buy_unit': 'UN',
#      'variable_weight': None,
#      'currency': 'BRL',
#      'unit_conversion_rate': None,
#      'is_tobacco': False,
#      'purchasable': True,
#      'pricing': {'original_price': {'label': 'ORIGINAL_PRICE',
#        'amount': 33.99,
#        'currency': 'BRL'},
#       'price': {'label': 'Preço', 'amount': 25.65, 'currency': 'BRL'},
#       'price_per_unit': None},
#      'price_per_unit': '',
#      'regulatory_fees': [],
#      'price': 25.65,
#      'original_price': '33.99',
#      'label': 'Ver Promo',
#      'description_sections': [{'title': 'Ofertas Especiais com entrega grátis',
#        'text': 'Comprando R$280 em produtos Ofertas Especiais marcados com a promoção, você não paga a entrega.',
#        'type': 'DELIVERY'},
#       {'title': 'Promoção Carrefour Hiper',
#        'text': 'Desconto exclusivo Carrefour Hiper',
#        'type': 'DISCOUNT'}],
#      'availability_status': 'AVAILABLE',
#      'nutritional_info': None,
#      'name': 'Amaciante de roupas concentrado Brisa de Verão',
#      'description': 'Amaciante concentrado que deixa as suas roupas perfumadas por mais tempo*! Downy Brisa resultadas da combinação de flores brancas e cítricas e do frescor do herbal e âmbar. A fórmula de Downy possui microcápsulas de perfume especiais que se ativam com o toque, liberando perfume ao longo de todo o dia. Além disso, protege de odores desagradáveis como fumaça, fritura e suor, os impedindo de impregnar nas roupas**. Desta forma você se veste de perfume o dia todo. Por ser concentrado, 1.5L de Downy é equivalente a 6L de um amaciante diluído comum. Isso significa que ele rende até 66 lavagens. Para garantir um melhor uso, utilize apenas a quantidade de amaciante indicada na embalagem do produto. *Concentração de perfume depositada e liberada do tecido seco medida por métodos analíticos vs. amaciantes não concentrados **Baseado em provas realizadas com conjunto de odores representativos',
#      'package': '1,5l',
#      'img_url': 'https://s.cornershopapp.com/product-images/1191770.jpg?versionId=2.ZgxKwn9gbRHrkKRxB1PhXo65UGUykU',
#      'extra_img_urls': []},
#     {'id': 1258284,
#      'brand': {'id': 73710, 'name': 'Ypê'},
#      'kind': 'PRODUCT',
#      'related_to': None,
#      'buy_unit': 'UN',
#      'default_buy_unit': 'UN',
#      'variable_weight': False,
#      'currency': 'BRL',
#      'unit_conversion_rate': None,
#      'is_tobacco': False,
#      'purchasable': True,
#      'pricing': {'original_price': {'label': 'ORIGINAL_PRICE',
#        'amount': 24.99,
#        'currency': 'BRL'},
#       'price': {'label': 'Preço', 'amount': 19.99, 'currency': 'BRL'},
#       'price_per_unit': None},
#      'price_per_unit': '',
#      'regulatory_fees': [],
#      'price': 19.99,
#      'original_price': '24.99',
#      'label': '20 % OFF',
#      'description_sections': [{'title': 'Amaciantes com 20% de desconto',
#        'text': 'Receba 20% de desconto em produtos marcados com a promoção. Verifique termos e condições.',
#        'type': 'DISCOUNT'},
#       {'title': 'Ofertas Especiais com entrega grátis',
#        'text': 'Comprando R$280 em produtos Ofertas Especiais marcados com a promoção, você não paga a entrega.',
#        'type': 'DELIVERY'}],
#      'availability_status': 'AVAILABLE',
#      'nutritional_info': None,
#      'name': 'Amaciante de roupas Aconchego',
#      'description': 'Embalagem promocional leve 5l e pague 4,5l',
#      'package': '5l',
#      'img_url': 'https://s.cornershopapp.com/product-images/1258284.jpg?versionId=47fyTmBcsh9UuJJDly51ZPBa2Bzw5HKQ',
#      'extra_img_urls': []},
#     {'id': 1313371,
#      'brand': {'id': 66629, 'name': 'Comfort'},
#      'kind': 'PRODUCT',
#      'related_to': None,
#      'buy_unit': 'UN',
#      'default_buy_unit': 'UN',
#      'variable_weight': None,
#      'currency': 'BRL',
#      'unit_conversion_rate': None,
#      'is_tobacco': False,
#      'purchasable': True,
#      'pricing': {'original_price': None,
#       'price': {'label': 'Preço', 'amount': 31.69, 'currency': 'BRL'},
#       'price_per_unit': None},
#      'price_per_unit': '',
#      'regulatory_fees': [],
#      'price': 31.69,
#      'original_price': None,
#      'label': 'Ver Promo',
#      'description_sections': [{'title': 'Ofertas Especiais com entrega grátis',
#        'text': 'Comprando R$280 em produtos Ofertas Especiais marcados com a promoção, você não paga a entrega.',
#        'type': 'DELIVERY'}],
#      'availability_status': 'AVAILABLE',
#      'nutritional_info': None,
#      'name': 'Amaciante concentrado para roupas cuidado intensivo óleo de argan',
#      'description': 'Rende 6,7 litros.',
#      'package': '1,5l',
#      'img_url': 'https://s.cornershopapp.com/product-images/1313371.jpg?versionId=9dnSRos4ZWVdhw3.wLqDDNABBJGnvgen',
#      'extra_img_urls': []},
#     {'id': 1258221,
#      'brand': {'id': 66629, 'name': 'Comfort'},
#      'kind': 'PRODUCT',
#      'related_to': None,
#      'buy_unit': 'UN',
#      'default_buy_unit': 'UN',
#      'variable_weight': None,
#      'currency': 'BRL',
#      'unit_conversion_rate': None,
#      'is_tobacco': False,
#      'purchasable': True,
#      'pricing': {'original_price': None,
#       'price': {'label': 'Preço', 'amount': 21.89, 'currency': 'BRL'},
#       'price_per_unit': None},
#      'price_per_unit': '',
#      'regulatory_fees': [],
#      'price': 21.89,
#      'original_price': None,
#      'label': 'Ver Promo',
#      'description_sections': [{'title': 'Ofertas Especiais com entrega grátis',
#        'text': 'Comprando R$280 em produtos Ofertas Especiais marcados com a promoção, você não paga a entrega.',
#        'type': 'DELIVERY'}],
#      'availability_status': 'AVAILABLE',
#      'nutritional_info': None,
#      'name': 'Refil de amaciante de roupas concentrado Original',
#      'description': 'Refil amaciante de roupa concentrado original intensivo cuidado essencial Confort.',
#      'package': '900ml',
#      'img_url': 'https://s.cornershopapp.com/product-images/1258221.jpg?versionId=9O.dcr.VipUrv7QH5bOKAzB_soEFtx.r',
#      'extra_img_urls': []},
#     {'id': 1316764,
#      'brand': {'id': 66629, 'name': 'Comfort'},
#      'kind': 'PRODUCT',
#      'related_to': None,
#      'buy_unit': 'UN',
#      'default_buy_unit': 'UN',
#      'variable_weight': False,
#      'currency': 'BRL',
#      'unit_conversion_rate': None,
#      'is_tobacco': False,
#      'purchasable': True,
#      'pricing': {'original_price': None,
#       'price': {'label': 'Preço', 'amount': 21.89, 'currency': 'BRL'},
#       'price_per_unit': None},
#      'price_per_unit': '',
#      'regulatory_fees': [],
#      'price': 21.89,
#      'original_price': None,
#      'label': 'Ver Promo',
#      'description_sections': [{'title': 'Ofertas Especiais com entrega grátis',
#        'text': 'Comprando R$280 em produtos Ofertas Especiais marcados com a promoção, você não paga a entrega.',
#        'type': 'DELIVERY'}],
#      'availability_status': 'AVAILABLE',
#      'nutritional_info': None,
#      'name': 'Refil de amaciante de roupas concentrado hipoalergênico',
#      'description': '.',
#      'package': '900ml',
#      'img_url': 'https://s.cornershopapp.com/product-images/1316764.jpg?versionId=xIjYKT2_uC_mYfUvRwrgkFhupsjlxilP',
#      'extra_img_urls': []},
#     {'id': 1191776,
#      'brand': {'id': 659, 'name': 'Downy'},
#      'kind': 'PRODUCT',
#      'related_to': None,
#      'buy_unit': 'UN',
#      'default_buy_unit': 'UN',
#      'variable_weight': None,
#      'currency': 'BRL',
#      'unit_conversion_rate': None,
#      'is_tobacco': False,
#      'purchasable': True,
#      'pricing': {'original_price': None,
#       'price': {'label': 'Preço', 'amount': 13.19, 'currency': 'BRL'},
#       'price_per_unit': None},
#      'price_per_unit': '',
#      'regulatory_fees': [],
#      'price': 13.19,
#      'original_price': None,
#      'label': None,
#      'description_sections': [],
#      'availability_status': 'AVAILABLE',
#      'nutritional_info': None,
#      'name': 'Amaciante de roupas concentrado Lírios do Campo',
#      'description': 'Amaciante concentrado que deixa as suas roupas perfumadas por mais tempo*! Downy Lírios do Campo possuí notas de perfume de rosas com um toque de flor de laranjeira, resultando em uma fragrância levemente adocicada. A fórmula de Downy possui microcápsulas de perfume especiais que se ativam com o toque, liberando perfume ao longo de todo o dia. Além disso, protege de odores desagradáveis como fumaça, fritura e suor, os impedindo de impregnar nas roupas**. Desta forma você se veste de perfume o dia todo. Por ser concentrado, 1.5L de Downy é equivalente a 6L de um amaciante diluído comum. Isso significa que ele rende até 66 lavagens. Para garantir um melhor uso, utilize apenas a quantidade de amaciante indicada na embalagem do produto. *Concentração de perfume depositada e liberada do tecido seco medida por métodos analíticos vs. amaciantes não concentrados **Baseado em provas realizadas com conjunto de odores representativos',
#      'package': '500g',
#      'img_url': 'https://s.cornershopapp.com/product-images/1191776.jpg?versionId=q9xhPumySv98bDUDJjB2Z3ylRyTGx.mE',
#      'extra_img_urls': []},
#     {'id': 1315722,
#      'brand': {'id': 66629, 'name': 'Comfort'},
#      'kind': 'PRODUCT',
#      'related_to': None,
#      'buy_unit': 'UN',
#      'default_buy_unit': 'UN',
#      'variable_weight': False,
#      'currency': 'BRL',
#      'unit_conversion_rate': None,
#      'is_tobacco': False,
#      'purchasable': True,
#      'pricing': {'original_price': None,
#       'price': {'label': 'Preço', 'amount': 31.69, 'currency': 'BRL'},
#       'price_per_unit': None},
#      'price_per_unit': '',
#      'regulatory_fees': [],
#      'price': 31.69,
#      'original_price': None,
#      'label': 'Ver Promo',
#      'description_sections': [{'title': 'Ofertas Especiais com entrega grátis',
#        'text': 'Comprando R$280 em produtos Ofertas Especiais marcados com a promoção, você não paga a entrega.',
#        'type': 'DELIVERY'}],
#      'availability_status': 'AVAILABLE',
#      'nutritional_info': None,
#      'name': 'Amaciante de roupas concentrado Puro Cuidado',
#      'description': 'Amaciante de roupas concentrado Puro Cuidado hipoalergênico óleo de argan',
#      'package': 'Garrafa 1,5l',
#      'img_url': 'https://s.cornershopapp.com/product-images/1315722.jpg?versionId=BUpObFsRuI9y0_pjFH_k_wcz8SbuKzV3',
#      'extra_img_urls': []},
#     {'id': 1191787,
#      'brand': {'id': 66629, 'name': 'Comfort'},
#      'kind': 'PRODUCT',
#      'related_to': None,
#      'buy_unit': 'UN',
#      'default_buy_unit': 'UN',
#      'variable_weight': False,
#      'currency': 'BRL',
#      'unit_conversion_rate': None,
#      'is_tobacco': False,
#      'purchasable': True,
#      'pricing': {'original_price': None,
#       'price': {'label': 'Preço', 'amount': 22.99, 'currency': 'BRL'},
#       'price_per_unit': None},
#      'price_per_unit': '',
#      'regulatory_fees': [],
#      'price': 22.99,
#      'original_price': None,
#      'label': None,
#      'description_sections': [],
#      'availability_status': 'AVAILABLE',
#      'nutritional_info': None,
#      'name': 'Amaciante de roupas concentrado intense com óleo de argan',
#      'description': None,
#      'package': '1l',
#      'img_url': 'https://s.cornershopapp.com/product-images/1191787.jpg?versionId=naRBJ3eQ9K8IbLw2228va.F2DWDMFZ0U',
#      'extra_img_urls': []},
#     {'id': 1191778,
#      'brand': {'id': 66629, 'name': 'Comfort'},
#      'kind': 'PRODUCT',
#      'related_to': None,
#      'buy_unit': 'UN',
#      'default_buy_unit': 'UN',
#      'variable_weight': False,
#      'currency': 'BRL',
#      'unit_conversion_rate': None,
#      'is_tobacco': False,
#      'purchasable': True,
#      'pricing': {'original_price': None,
#       'price': {'label': 'Preço', 'amount': 22.99, 'currency': 'BRL'},
#       'price_per_unit': None},
#      'price_per_unit': '',
#      'regulatory_fees': [],
#      'price': 22.99,
#      'original_price': None,
#      'label': None,
#      'description_sections': [],
#      'availability_status': 'AVAILABLE',
#      'nutritional_info': None,
#      'name': 'Amaciante de roupa concentrado cuidado intensivo com óleo de argan',
#      'description': None,
#      'package': '1l',
#      'img_url': 'https://s.cornershopapp.com/product-images/1191778.jpg?versionId=CiEyR3vsf_e94dRrpVOgcvCAViKbct.U',
#      'extra_img_urls': []},
#     {'id': 1191782,
#      'brand': {'id': 66629, 'name': 'Comfort'},
#      'kind': 'PRODUCT',
#      'related_to': None,
#      'buy_unit': 'UN',
#      'default_buy_unit': 'UN',
#      'variable_weight': None,
#      'currency': 'BRL',
#      'unit_conversion_rate': None,
#      'is_tobacco': False,
#      'purchasable': True,
#      'pricing': {'original_price': None,
#       'price': {'label': 'Preço', 'amount': 22.99, 'currency': 'BRL'},
#       'price_per_unit': None},
#      'price_per_unit': '',
#      'regulatory_fees': [],
#      'price': 22.99,
#      'original_price': None,
#      'label': None,
#      'description_sections': [],
#      'availability_status': 'AVAILABLE',
#      'nutritional_info': None,
#      'name': 'Amaciante de roupa concentrado Glamour',
#      'description': 'Amaciante concentrado Comfort, extrema maciez com exclusivo perfume envolvente. Cuidadosamente desenvolvido para deixar os tecidos macios e fáceis de passar e com um delicioso perfume encantador e duradouro.',
#      'package': '1l',
#      'img_url': 'https://s.cornershopapp.com/product-images/1191782.jpg?versionId=bMiuU2nXMS5R5FJjvCTvXYOYelXZORA6',
#      'extra_img_urls': []}]}]}

# %% [markdown]
# `search_result` contém informações sobre o produto

# %% [markdown]
# Vamos verificar o que diferencia cada um dos dos oito objetos que retornaram

# %%
# print do id e nome da loja para cada objeto em stores
for result in results:
    result_id = result.get('store', {}).get('id')
    result_name = result.get('store', {}).get('name')
    print(f"({result_id}) {result_name}")
# Out:
# (1327) Carrefour Hiper
# (11083) Angeloni Supermercados
# (15002) BIG by Carrefour
# (3101) Atacadão
# (6969) Hippo
# (14798) Drogaria Catarinense
# (6049) Droga Raia
# (14797) Farmácia Preço Popular

# %% [markdown]
# Parece que a diferenciação se dá pelo marca/loja.
# Mas cada marca tem lojas em diferentes locais.
# Será que

# %%
# O que temos dentro do objeto atual?
results[0]['search_result'].keys()
# Out:
# dict_keys(['search_term', 'aisles'])

# %%
# verificando o que tem no primeiro objeto
results[0]['search_result']['search_term']
# Out:
# 'amaciante'

# %% [markdown]
# é apenas o termo de busca

# %%
# verificando o que tem no segundo objeto
results[0]['search_result']['aisles']
# Out:
# [{'aisle_id': 'C_1582',
#   'aisle_name': 'Amaciantes',
#   'department_id': 'C_983',
#   'products': [{'id': 1191812,
#     'brand': {'id': 73710, 'name': 'Ypê'},
#     'kind': 'PRODUCT',
#     'related_to': None,
#     'buy_unit': 'UN',
#     'default_buy_unit': 'UN',
#     'variable_weight': None,
#     'currency': 'BRL',
#     'unit_conversion_rate': None,
#     'is_tobacco': False,
#     'purchasable': True,
#     'pricing': {'original_price': {'label': 'ORIGINAL_PRICE',
#       'amount': 12.19,
#       'currency': 'BRL'},
#      'price': {'label': 'Preço', 'amount': 9.75, 'currency': 'BRL'},
#      'price_per_unit': None},
#     'price_per_unit': '',
#     'regulatory_fees': [],
#     'price': 9.75,
#     'original_price': '12.19',
#     'label': '20 % OFF',
#     'description_sections': [{'title': 'Amaciantes com 20% de desconto',
#       'text': 'Receba 20% de desconto em produtos marcados com a promoção. Verifique termos e condições.',
#       'type': 'DISCOUNT'}],
#     'availability_status': 'AVAILABLE',
#     'nutritional_info': None,
#     'name': 'Amaciante de roupas intenso',
#     'description': 'O Amaciante Ypê está com uma nova fórmula. Tem mais perfume e o toque mágico com Hidraceramidas, para roupas mais perfumadas e macias.',
#     'package': '2l',
#     'img_url': 'https://s.cornershopapp.com/product-images/1191812.png?versionId=07SCwy3Zm8h04uvoiIyqBZPApRhLepPT',
#     'extra_img_urls': []},
#    {'id': 1265631,
#     'brand': {'id': 73710, 'name': 'Ypê'},
#     'kind': 'PRODUCT',
#     'related_to': None,
#     'buy_unit': 'UN',
#     'default_buy_unit': 'UN',
#     'variable_weight': None,
#     'currency': 'BRL',
#     'unit_conversion_rate': None,
#     'is_tobacco': False,
#     'purchasable': True,
#     'pricing': {'original_price': {'label': 'ORIGINAL_PRICE',
#       'amount': 12.19,
#       'currency': 'BRL'},
#      'price': {'label': 'Preço', 'amount': 9.75, 'currency': 'BRL'},
#      'price_per_unit': None},
#     'price_per_unit': '',
#     'regulatory_fees': [],
#     'price': 9.75,
#     'original_price': '12.19',
#     'label': '20 % OFF',
#     'description_sections': [{'title': 'Amaciantes com 20% de desconto',
#       'text': 'Receba 20% de desconto em produtos marcados com a promoção. Verifique termos e condições.',
#       'type': 'DISCOUNT'}],
#     'availability_status': 'AVAILABLE',
#     'nutritional_info': None,
#     'name': 'Amaciante de roupas Aconchego',
#     'description': '',
#     'package': '2l',
#     'img_url': 'https://s.cornershopapp.com/product-images/1265631.png?versionId=c2eMNDfLXKs5ENLq1J8op8ftAxnRD0VH',
#     'extra_img_urls': []},
#    {'id': 1191769,
#     'brand': {'id': 659, 'name': 'Downy'},
#     'kind': 'PRODUCT',
#     'related_to': None,
#     'buy_unit': 'UN',
#     'default_buy_unit': 'UN',
#     'variable_weight': False,
#     'currency': 'BRL',
#     'unit_conversion_rate': None,
#     'is_tobacco': False,
#     'purchasable': True,
#     'pricing': {'original_price': None,
#      'price': {'label': 'Preço', 'amount': 25.59, 'currency': 'BRL'},
#      'price_per_unit': None},
#     'price_per_unit': '',
#     'regulatory_fees': [],
#     'price': 25.59,
#     'original_price': None,
#     'label': 'Ver Promo',
#     'description_sections': [{'title': 'Ofertas Especiais com entrega grátis',
#       'text': 'Comprando R$280 em produtos Ofertas Especiais marcados com a promoção, você não paga a entrega.',
#       'type': 'DELIVERY'}],
#     'availability_status': 'AVAILABLE',
#     'nutritional_info': None,
#     'name': 'Amaciante de roupas concentrado Brisa de Verão',
#     'description': 'Amaciante concentrado que deixa as suas roupas perfumadas por mais tempo*! Downy Brisa resultadas da combinação de flores brancas e cítricas e do frescor do herbal e âmbar. A fórmula de Downy possui microcápsulas de perfume especiais que se ativam com o toque, liberando perfume ao longo de todo o dia. Além disso, protege de odores desagradáveis como fumaça, fritura e suor, os impedindo de impregnar nas roupas**. Desta forma você se veste de perfume o dia todo. Por ser concentrado, 1.5L de Downy é equivalente a 6L de um amaciante diluído comum. Isso significa que ele rende até 66 lavagens. Para garantir um melhor uso, utilize apenas a quantidade de amaciante indicada na embalagem do produto. *Concentração de perfume depositada e liberada do tecido seco medida por métodos analíticos vs. amaciantes não concentrados **Baseado em provas realizadas com conjunto de odores representativos',
#     'package': '1l',
#     'img_url': 'https://s.cornershopapp.com/product-images/1191769.jpg?versionId=Hb1SFC8lD.f5cWUUwR.B.1LRVYDXepa9',
#     'extra_img_urls': []},
#    {'id': 1191770,
#     'brand': {'id': 659, 'name': 'Downy'},
#     'kind': 'PRODUCT',
#     'related_to': None,
#     'buy_unit': 'UN',
#     'default_buy_unit': 'UN',
#     'variable_weight': None,
#     'currency': 'BRL',
#     'unit_conversion_rate': None,
#     'is_tobacco': False,
#     'purchasable': True,
#     'pricing': {'original_price': {'label': 'ORIGINAL_PRICE',
#       'amount': 33.99,
#       'currency': 'BRL'},
#      'price': {'label': 'Preço', 'amount': 25.65, 'currency': 'BRL'},
#      'price_per_unit': None},
#     'price_per_unit': '',
#     'regulatory_fees': [],
#     'price': 25.65,
#     'original_price': '33.99',
#     'label': 'Ver Promo',
#     'description_sections': [{'title': 'Ofertas Especiais com entrega grátis',
#       'text': 'Comprando R$280 em produtos Ofertas Especiais marcados com a promoção, você não paga a entrega.',
#       'type': 'DELIVERY'},
#      {'title': 'Promoção Carrefour Hiper',
#       'text': 'Desconto exclusivo Carrefour Hiper',
#       'type': 'DISCOUNT'}],
#     'availability_status': 'AVAILABLE',
#     'nutritional_info': None,
#     'name': 'Amaciante de roupas concentrado Brisa de Verão',
#     'description': 'Amaciante concentrado que deixa as suas roupas perfumadas por mais tempo*! Downy Brisa resultadas da combinação de flores brancas e cítricas e do frescor do herbal e âmbar. A fórmula de Downy possui microcápsulas de perfume especiais que se ativam com o toque, liberando perfume ao longo de todo o dia. Além disso, protege de odores desagradáveis como fumaça, fritura e suor, os impedindo de impregnar nas roupas**. Desta forma você se veste de perfume o dia todo. Por ser concentrado, 1.5L de Downy é equivalente a 6L de um amaciante diluído comum. Isso significa que ele rende até 66 lavagens. Para garantir um melhor uso, utilize apenas a quantidade de amaciante indicada na embalagem do produto. *Concentração de perfume depositada e liberada do tecido seco medida por métodos analíticos vs. amaciantes não concentrados **Baseado em provas realizadas com conjunto de odores representativos',
#     'package': '1,5l',
#     'img_url': 'https://s.cornershopapp.com/product-images/1191770.jpg?versionId=2.ZgxKwn9gbRHrkKRxB1PhXo65UGUykU',
#     'extra_img_urls': []},
#    {'id': 1258284,
#     'brand': {'id': 73710, 'name': 'Ypê'},
#     'kind': 'PRODUCT',
#     'related_to': None,
#     'buy_unit': 'UN',
#     'default_buy_unit': 'UN',
#     'variable_weight': False,
#     'currency': 'BRL',
#     'unit_conversion_rate': None,
#     'is_tobacco': False,
#     'purchasable': True,
#     'pricing': {'original_price': {'label': 'ORIGINAL_PRICE',
#       'amount': 24.99,
#       'currency': 'BRL'},
#      'price': {'label': 'Preço', 'amount': 19.99, 'currency': 'BRL'},
#      'price_per_unit': None},
#     'price_per_unit': '',
#     'regulatory_fees': [],
#     'price': 19.99,
#     'original_price': '24.99',
#     'label': '20 % OFF',
#     'description_sections': [{'title': 'Amaciantes com 20% de desconto',
#       'text': 'Receba 20% de desconto em produtos marcados com a promoção. Verifique termos e condições.',
#       'type': 'DISCOUNT'},
#      {'title': 'Ofertas Especiais com entrega grátis',
#       'text': 'Comprando R$280 em produtos Ofertas Especiais marcados com a promoção, você não paga a entrega.',
#       'type': 'DELIVERY'}],
#     'availability_status': 'AVAILABLE',
#     'nutritional_info': None,
#     'name': 'Amaciante de roupas Aconchego',
#     'description': 'Embalagem promocional leve 5l e pague 4,5l',
#     'package': '5l',
#     'img_url': 'https://s.cornershopapp.com/product-images/1258284.jpg?versionId=47fyTmBcsh9UuJJDly51ZPBa2Bzw5HKQ',
#     'extra_img_urls': []},
#    {'id': 1313371,
#     'brand': {'id': 66629, 'name': 'Comfort'},
#     'kind': 'PRODUCT',
#     'related_to': None,
#     'buy_unit': 'UN',
#     'default_buy_unit': 'UN',
#     'variable_weight': None,
#     'currency': 'BRL',
#     'unit_conversion_rate': None,
#     'is_tobacco': False,
#     'purchasable': True,
#     'pricing': {'original_price': None,
#      'price': {'label': 'Preço', 'amount': 31.69, 'currency': 'BRL'},
#      'price_per_unit': None},
#     'price_per_unit': '',
#     'regulatory_fees': [],
#     'price': 31.69,
#     'original_price': None,
#     'label': 'Ver Promo',
#     'description_sections': [{'title': 'Ofertas Especiais com entrega grátis',
#       'text': 'Comprando R$280 em produtos Ofertas Especiais marcados com a promoção, você não paga a entrega.',
#       'type': 'DELIVERY'}],
#     'availability_status': 'AVAILABLE',
#     'nutritional_info': None,
#     'name': 'Amaciante concentrado para roupas cuidado intensivo óleo de argan',
#     'description': 'Rende 6,7 litros.',
#     'package': '1,5l',
#     'img_url': 'https://s.cornershopapp.com/product-images/1313371.jpg?versionId=9dnSRos4ZWVdhw3.wLqDDNABBJGnvgen',
#     'extra_img_urls': []},
#    {'id': 1258221,
#     'brand': {'id': 66629, 'name': 'Comfort'},
#     'kind': 'PRODUCT',
#     'related_to': None,
#     'buy_unit': 'UN',
#     'default_buy_unit': 'UN',
#     'variable_weight': None,
#     'currency': 'BRL',
#     'unit_conversion_rate': None,
#     'is_tobacco': False,
#     'purchasable': True,
#     'pricing': {'original_price': None,
#      'price': {'label': 'Preço', 'amount': 21.89, 'currency': 'BRL'},
#      'price_per_unit': None},
#     'price_per_unit': '',
#     'regulatory_fees': [],
#     'price': 21.89,
#     'original_price': None,
#     'label': 'Ver Promo',
#     'description_sections': [{'title': 'Ofertas Especiais com entrega grátis',
#       'text': 'Comprando R$280 em produtos Ofertas Especiais marcados com a promoção, você não paga a entrega.',
#       'type': 'DELIVERY'}],
#     'availability_status': 'AVAILABLE',
#     'nutritional_info': None,
#     'name': 'Refil de amaciante de roupas concentrado Original',
#     'description': 'Refil amaciante de roupa concentrado original intensivo cuidado essencial Confort.',
#     'package': '900ml',
#     'img_url': 'https://s.cornershopapp.com/product-images/1258221.jpg?versionId=9O.dcr.VipUrv7QH5bOKAzB_soEFtx.r',
#     'extra_img_urls': []},
#    {'id': 1316764,
#     'brand': {'id': 66629, 'name': 'Comfort'},
#     'kind': 'PRODUCT',
#     'related_to': None,
#     'buy_unit': 'UN',
#     'default_buy_unit': 'UN',
#     'variable_weight': False,
#     'currency': 'BRL',
#     'unit_conversion_rate': None,
#     'is_tobacco': False,
#     'purchasable': True,
#     'pricing': {'original_price': None,
#      'price': {'label': 'Preço', 'amount': 21.89, 'currency': 'BRL'},
#      'price_per_unit': None},
#     'price_per_unit': '',
#     'regulatory_fees': [],
#     'price': 21.89,
#     'original_price': None,
#     'label': 'Ver Promo',
#     'description_sections': [{'title': 'Ofertas Especiais com entrega grátis',
#       'text': 'Comprando R$280 em produtos Ofertas Especiais marcados com a promoção, você não paga a entrega.',
#       'type': 'DELIVERY'}],
#     'availability_status': 'AVAILABLE',
#     'nutritional_info': None,
#     'name': 'Refil de amaciante de roupas concentrado hipoalergênico',
#     'description': '.',
#     'package': '900ml',
#     'img_url': 'https://s.cornershopapp.com/product-images/1316764.jpg?versionId=xIjYKT2_uC_mYfUvRwrgkFhupsjlxilP',
#     'extra_img_urls': []},
#    {'id': 1191776,
#     'brand': {'id': 659, 'name': 'Downy'},
#     'kind': 'PRODUCT',
#     'related_to': None,
#     'buy_unit': 'UN',
#     'default_buy_unit': 'UN',
#     'variable_weight': None,
#     'currency': 'BRL',
#     'unit_conversion_rate': None,
#     'is_tobacco': False,
#     'purchasable': True,
#     'pricing': {'original_price': None,
#      'price': {'label': 'Preço', 'amount': 13.19, 'currency': 'BRL'},
#      'price_per_unit': None},
#     'price_per_unit': '',
#     'regulatory_fees': [],
#     'price': 13.19,
#     'original_price': None,
#     'label': None,
#     'description_sections': [],
#     'availability_status': 'AVAILABLE',
#     'nutritional_info': None,
#     'name': 'Amaciante de roupas concentrado Lírios do Campo',
#     'description': 'Amaciante concentrado que deixa as suas roupas perfumadas por mais tempo*! Downy Lírios do Campo possuí notas de perfume de rosas com um toque de flor de laranjeira, resultando em uma fragrância levemente adocicada. A fórmula de Downy possui microcápsulas de perfume especiais que se ativam com o toque, liberando perfume ao longo de todo o dia. Além disso, protege de odores desagradáveis como fumaça, fritura e suor, os impedindo de impregnar nas roupas**. Desta forma você se veste de perfume o dia todo. Por ser concentrado, 1.5L de Downy é equivalente a 6L de um amaciante diluído comum. Isso significa que ele rende até 66 lavagens. Para garantir um melhor uso, utilize apenas a quantidade de amaciante indicada na embalagem do produto. *Concentração de perfume depositada e liberada do tecido seco medida por métodos analíticos vs. amaciantes não concentrados **Baseado em provas realizadas com conjunto de odores representativos',
#     'package': '500g',
#     'img_url': 'https://s.cornershopapp.com/product-images/1191776.jpg?versionId=q9xhPumySv98bDUDJjB2Z3ylRyTGx.mE',
#     'extra_img_urls': []},
#    {'id': 1315722,
#     'brand': {'id': 66629, 'name': 'Comfort'},
#     'kind': 'PRODUCT',
#     'related_to': None,
#     'buy_unit': 'UN',
#     'default_buy_unit': 'UN',
#     'variable_weight': False,
#     'currency': 'BRL',
#     'unit_conversion_rate': None,
#     'is_tobacco': False,
#     'purchasable': True,
#     'pricing': {'original_price': None,
#      'price': {'label': 'Preço', 'amount': 31.69, 'currency': 'BRL'},
#      'price_per_unit': None},
#     'price_per_unit': '',
#     'regulatory_fees': [],
#     'price': 31.69,
#     'original_price': None,
#     'label': 'Ver Promo',
#     'description_sections': [{'title': 'Ofertas Especiais com entrega grátis',
#       'text': 'Comprando R$280 em produtos Ofertas Especiais marcados com a promoção, você não paga a entrega.',
#       'type': 'DELIVERY'}],
#     'availability_status': 'AVAILABLE',
#     'nutritional_info': None,
#     'name': 'Amaciante de roupas concentrado Puro Cuidado',
#     'description': 'Amaciante de roupas concentrado Puro Cuidado hipoalergênico óleo de argan',
#     'package': 'Garrafa 1,5l',
#     'img_url': 'https://s.cornershopapp.com/product-images/1315722.jpg?versionId=BUpObFsRuI9y0_pjFH_k_wcz8SbuKzV3',
#     'extra_img_urls': []},
#    {'id': 1191787,
#     'brand': {'id': 66629, 'name': 'Comfort'},
#     'kind': 'PRODUCT',
#     'related_to': None,
#     'buy_unit': 'UN',
#     'default_buy_unit': 'UN',
#     'variable_weight': False,
#     'currency': 'BRL',
#     'unit_conversion_rate': None,
#     'is_tobacco': False,
#     'purchasable': True,
#     'pricing': {'original_price': None,
#      'price': {'label': 'Preço', 'amount': 22.99, 'currency': 'BRL'},
#      'price_per_unit': None},
#     'price_per_unit': '',
#     'regulatory_fees': [],
#     'price': 22.99,
#     'original_price': None,
#     'label': None,
#     'description_sections': [],
#     'availability_status': 'AVAILABLE',
#     'nutritional_info': None,
#     'name': 'Amaciante de roupas concentrado intense com óleo de argan',
#     'description': None,
#     'package': '1l',
#     'img_url': 'https://s.cornershopapp.com/product-images/1191787.jpg?versionId=naRBJ3eQ9K8IbLw2228va.F2DWDMFZ0U',
#     'extra_img_urls': []},
#    {'id': 1191778,
#     'brand': {'id': 66629, 'name': 'Comfort'},
#     'kind': 'PRODUCT',
#     'related_to': None,
#     'buy_unit': 'UN',
#     'default_buy_unit': 'UN',
#     'variable_weight': False,
#     'currency': 'BRL',
#     'unit_conversion_rate': None,
#     'is_tobacco': False,
#     'purchasable': True,
#     'pricing': {'original_price': None,
#      'price': {'label': 'Preço', 'amount': 22.99, 'currency': 'BRL'},
#      'price_per_unit': None},
#     'price_per_unit': '',
#     'regulatory_fees': [],
#     'price': 22.99,
#     'original_price': None,
#     'label': None,
#     'description_sections': [],
#     'availability_status': 'AVAILABLE',
#     'nutritional_info': None,
#     'name': 'Amaciante de roupa concentrado cuidado intensivo com óleo de argan',
#     'description': None,
#     'package': '1l',
#     'img_url': 'https://s.cornershopapp.com/product-images/1191778.jpg?versionId=CiEyR3vsf_e94dRrpVOgcvCAViKbct.U',
#     'extra_img_urls': []},
#    {'id': 1191782,
#     'brand': {'id': 66629, 'name': 'Comfort'},
#     'kind': 'PRODUCT',
#     'related_to': None,
#     'buy_unit': 'UN',
#     'default_buy_unit': 'UN',
#     'variable_weight': None,
#     'currency': 'BRL',
#     'unit_conversion_rate': None,
#     'is_tobacco': False,
#     'purchasable': True,
#     'pricing': {'original_price': None,
#      'price': {'label': 'Preço', 'amount': 22.99, 'currency': 'BRL'},
#      'price_per_unit': None},
#     'price_per_unit': '',
#     'regulatory_fees': [],
#     'price': 22.99,
#     'original_price': None,
#     'label': None,
#     'description_sections': [],
#     'availability_status': 'AVAILABLE',
#     'nutritional_info': None,
#     'name': 'Amaciante de roupa concentrado Glamour',
#     'description': 'Amaciante concentrado Comfort, extrema maciez com exclusivo perfume envolvente. Cuidadosamente desenvolvido para deixar os tecidos macios e fáceis de passar e com um delicioso perfume encantador e duradouro.',
#     'package': '1l',
#     'img_url': 'https://s.cornershopapp.com/product-images/1191782.jpg?versionId=bMiuU2nXMS5R5FJjvCTvXYOYelXZORA6',
#     'extra_img_urls': []}]}]

# %% [markdown]
# Esse é o objeto que interessa!
# - o que significa `aisle_id`?

# %%
len(results[0]['search_result']['aisles'])
# Out:
# 1

# %% [markdown]
# Temos um conjunto com apenas um item

# %%
# extrai o objeto da array 
results[0]['search_result']['aisles'][0]
# Out:
# {'aisle_id': 'C_1582',
#  'aisle_name': 'Amaciantes',
#  'department_id': 'C_983',
#  'products': [{'id': 1191812,
#    'brand': {'id': 73710, 'name': 'Ypê'},
#    'kind': 'PRODUCT',
#    'related_to': None,
#    'buy_unit': 'UN',
#    'default_buy_unit': 'UN',
#    'variable_weight': None,
#    'currency': 'BRL',
#    'unit_conversion_rate': None,
#    'is_tobacco': False,
#    'purchasable': True,
#    'pricing': {'original_price': {'label': 'ORIGINAL_PRICE',
#      'amount': 12.19,
#      'currency': 'BRL'},
#     'price': {'label': 'Preço', 'amount': 9.75, 'currency': 'BRL'},
#     'price_per_unit': None},
#    'price_per_unit': '',
#    'regulatory_fees': [],
#    'price': 9.75,
#    'original_price': '12.19',
#    'label': '20 % OFF',
#    'description_sections': [{'title': 'Amaciantes com 20% de desconto',
#      'text': 'Receba 20% de desconto em produtos marcados com a promoção. Verifique termos e condições.',
#      'type': 'DISCOUNT'}],
#    'availability_status': 'AVAILABLE',
#    'nutritional_info': None,
#    'name': 'Amaciante de roupas intenso',
#    'description': 'O Amaciante Ypê está com uma nova fórmula. Tem mais perfume e o toque mágico com Hidraceramidas, para roupas mais perfumadas e macias.',
#    'package': '2l',
#    'img_url': 'https://s.cornershopapp.com/product-images/1191812.png?versionId=07SCwy3Zm8h04uvoiIyqBZPApRhLepPT',
#    'extra_img_urls': []},
#   {'id': 1265631,
#    'brand': {'id': 73710, 'name': 'Ypê'},
#    'kind': 'PRODUCT',
#    'related_to': None,
#    'buy_unit': 'UN',
#    'default_buy_unit': 'UN',
#    'variable_weight': None,
#    'currency': 'BRL',
#    'unit_conversion_rate': None,
#    'is_tobacco': False,
#    'purchasable': True,
#    'pricing': {'original_price': {'label': 'ORIGINAL_PRICE',
#      'amount': 12.19,
#      'currency': 'BRL'},
#     'price': {'label': 'Preço', 'amount': 9.75, 'currency': 'BRL'},
#     'price_per_unit': None},
#    'price_per_unit': '',
#    'regulatory_fees': [],
#    'price': 9.75,
#    'original_price': '12.19',
#    'label': '20 % OFF',
#    'description_sections': [{'title': 'Amaciantes com 20% de desconto',
#      'text': 'Receba 20% de desconto em produtos marcados com a promoção. Verifique termos e condições.',
#      'type': 'DISCOUNT'}],
#    'availability_status': 'AVAILABLE',
#    'nutritional_info': None,
#    'name': 'Amaciante de roupas Aconchego',
#    'description': '',
#    'package': '2l',
#    'img_url': 'https://s.cornershopapp.com/product-images/1265631.png?versionId=c2eMNDfLXKs5ENLq1J8op8ftAxnRD0VH',
#    'extra_img_urls': []},
#   {'id': 1191769,
#    'brand': {'id': 659, 'name': 'Downy'},
#    'kind': 'PRODUCT',
#    'related_to': None,
#    'buy_unit': 'UN',
#    'default_buy_unit': 'UN',
#    'variable_weight': False,
#    'currency': 'BRL',
#    'unit_conversion_rate': None,
#    'is_tobacco': False,
#    'purchasable': True,
#    'pricing': {'original_price': None,
#     'price': {'label': 'Preço', 'amount': 25.59, 'currency': 'BRL'},
#     'price_per_unit': None},
#    'price_per_unit': '',
#    'regulatory_fees': [],
#    'price': 25.59,
#    'original_price': None,
#    'label': 'Ver Promo',
#    'description_sections': [{'title': 'Ofertas Especiais com entrega grátis',
#      'text': 'Comprando R$280 em produtos Ofertas Especiais marcados com a promoção, você não paga a entrega.',
#      'type': 'DELIVERY'}],
#    'availability_status': 'AVAILABLE',
#    'nutritional_info': None,
#    'name': 'Amaciante de roupas concentrado Brisa de Verão',
#    'description': 'Amaciante concentrado que deixa as suas roupas perfumadas por mais tempo*! Downy Brisa resultadas da combinação de flores brancas e cítricas e do frescor do herbal e âmbar. A fórmula de Downy possui microcápsulas de perfume especiais que se ativam com o toque, liberando perfume ao longo de todo o dia. Além disso, protege de odores desagradáveis como fumaça, fritura e suor, os impedindo de impregnar nas roupas**. Desta forma você se veste de perfume o dia todo. Por ser concentrado, 1.5L de Downy é equivalente a 6L de um amaciante diluído comum. Isso significa que ele rende até 66 lavagens. Para garantir um melhor uso, utilize apenas a quantidade de amaciante indicada na embalagem do produto. *Concentração de perfume depositada e liberada do tecido seco medida por métodos analíticos vs. amaciantes não concentrados **Baseado em provas realizadas com conjunto de odores representativos',
#    'package': '1l',
#    'img_url': 'https://s.cornershopapp.com/product-images/1191769.jpg?versionId=Hb1SFC8lD.f5cWUUwR.B.1LRVYDXepa9',
#    'extra_img_urls': []},
#   {'id': 1191770,
#    'brand': {'id': 659, 'name': 'Downy'},
#    'kind': 'PRODUCT',
#    'related_to': None,
#    'buy_unit': 'UN',
#    'default_buy_unit': 'UN',
#    'variable_weight': None,
#    'currency': 'BRL',
#    'unit_conversion_rate': None,
#    'is_tobacco': False,
#    'purchasable': True,
#    'pricing': {'original_price': {'label': 'ORIGINAL_PRICE',
#      'amount': 33.99,
#      'currency': 'BRL'},
#     'price': {'label': 'Preço', 'amount': 25.65, 'currency': 'BRL'},
#     'price_per_unit': None},
#    'price_per_unit': '',
#    'regulatory_fees': [],
#    'price': 25.65,
#    'original_price': '33.99',
#    'label': 'Ver Promo',
#    'description_sections': [{'title': 'Ofertas Especiais com entrega grátis',
#      'text': 'Comprando R$280 em produtos Ofertas Especiais marcados com a promoção, você não paga a entrega.',
#      'type': 'DELIVERY'},
#     {'title': 'Promoção Carrefour Hiper',
#      'text': 'Desconto exclusivo Carrefour Hiper',
#      'type': 'DISCOUNT'}],
#    'availability_status': 'AVAILABLE',
#    'nutritional_info': None,
#    'name': 'Amaciante de roupas concentrado Brisa de Verão',
#    'description': 'Amaciante concentrado que deixa as suas roupas perfumadas por mais tempo*! Downy Brisa resultadas da combinação de flores brancas e cítricas e do frescor do herbal e âmbar. A fórmula de Downy possui microcápsulas de perfume especiais que se ativam com o toque, liberando perfume ao longo de todo o dia. Além disso, protege de odores desagradáveis como fumaça, fritura e suor, os impedindo de impregnar nas roupas**. Desta forma você se veste de perfume o dia todo. Por ser concentrado, 1.5L de Downy é equivalente a 6L de um amaciante diluído comum. Isso significa que ele rende até 66 lavagens. Para garantir um melhor uso, utilize apenas a quantidade de amaciante indicada na embalagem do produto. *Concentração de perfume depositada e liberada do tecido seco medida por métodos analíticos vs. amaciantes não concentrados **Baseado em provas realizadas com conjunto de odores representativos',
#    'package': '1,5l',
#    'img_url': 'https://s.cornershopapp.com/product-images/1191770.jpg?versionId=2.ZgxKwn9gbRHrkKRxB1PhXo65UGUykU',
#    'extra_img_urls': []},
#   {'id': 1258284,
#    'brand': {'id': 73710, 'name': 'Ypê'},
#    'kind': 'PRODUCT',
#    'related_to': None,
#    'buy_unit': 'UN',
#    'default_buy_unit': 'UN',
#    'variable_weight': False,
#    'currency': 'BRL',
#    'unit_conversion_rate': None,
#    'is_tobacco': False,
#    'purchasable': True,
#    'pricing': {'original_price': {'label': 'ORIGINAL_PRICE',
#      'amount': 24.99,
#      'currency': 'BRL'},
#     'price': {'label': 'Preço', 'amount': 19.99, 'currency': 'BRL'},
#     'price_per_unit': None},
#    'price_per_unit': '',
#    'regulatory_fees': [],
#    'price': 19.99,
#    'original_price': '24.99',
#    'label': '20 % OFF',
#    'description_sections': [{'title': 'Amaciantes com 20% de desconto',
#      'text': 'Receba 20% de desconto em produtos marcados com a promoção. Verifique termos e condições.',
#      'type': 'DISCOUNT'},
#     {'title': 'Ofertas Especiais com entrega grátis',
#      'text': 'Comprando R$280 em produtos Ofertas Especiais marcados com a promoção, você não paga a entrega.',
#      'type': 'DELIVERY'}],
#    'availability_status': 'AVAILABLE',
#    'nutritional_info': None,
#    'name': 'Amaciante de roupas Aconchego',
#    'description': 'Embalagem promocional leve 5l e pague 4,5l',
#    'package': '5l',
#    'img_url': 'https://s.cornershopapp.com/product-images/1258284.jpg?versionId=47fyTmBcsh9UuJJDly51ZPBa2Bzw5HKQ',
#    'extra_img_urls': []},
#   {'id': 1313371,
#    'brand': {'id': 66629, 'name': 'Comfort'},
#    'kind': 'PRODUCT',
#    'related_to': None,
#    'buy_unit': 'UN',
#    'default_buy_unit': 'UN',
#    'variable_weight': None,
#    'currency': 'BRL',
#    'unit_conversion_rate': None,
#    'is_tobacco': False,
#    'purchasable': True,
#    'pricing': {'original_price': None,
#     'price': {'label': 'Preço', 'amount': 31.69, 'currency': 'BRL'},
#     'price_per_unit': None},
#    'price_per_unit': '',
#    'regulatory_fees': [],
#    'price': 31.69,
#    'original_price': None,
#    'label': 'Ver Promo',
#    'description_sections': [{'title': 'Ofertas Especiais com entrega grátis',
#      'text': 'Comprando R$280 em produtos Ofertas Especiais marcados com a promoção, você não paga a entrega.',
#      'type': 'DELIVERY'}],
#    'availability_status': 'AVAILABLE',
#    'nutritional_info': None,
#    'name': 'Amaciante concentrado para roupas cuidado intensivo óleo de argan',
#    'description': 'Rende 6,7 litros.',
#    'package': '1,5l',
#    'img_url': 'https://s.cornershopapp.com/product-images/1313371.jpg?versionId=9dnSRos4ZWVdhw3.wLqDDNABBJGnvgen',
#    'extra_img_urls': []},
#   {'id': 1258221,
#    'brand': {'id': 66629, 'name': 'Comfort'},
#    'kind': 'PRODUCT',
#    'related_to': None,
#    'buy_unit': 'UN',
#    'default_buy_unit': 'UN',
#    'variable_weight': None,
#    'currency': 'BRL',
#    'unit_conversion_rate': None,
#    'is_tobacco': False,
#    'purchasable': True,
#    'pricing': {'original_price': None,
#     'price': {'label': 'Preço', 'amount': 21.89, 'currency': 'BRL'},
#     'price_per_unit': None},
#    'price_per_unit': '',
#    'regulatory_fees': [],
#    'price': 21.89,
#    'original_price': None,
#    'label': 'Ver Promo',
#    'description_sections': [{'title': 'Ofertas Especiais com entrega grátis',
#      'text': 'Comprando R$280 em produtos Ofertas Especiais marcados com a promoção, você não paga a entrega.',
#      'type': 'DELIVERY'}],
#    'availability_status': 'AVAILABLE',
#    'nutritional_info': None,
#    'name': 'Refil de amaciante de roupas concentrado Original',
#    'description': 'Refil amaciante de roupa concentrado original intensivo cuidado essencial Confort.',
#    'package': '900ml',
#    'img_url': 'https://s.cornershopapp.com/product-images/1258221.jpg?versionId=9O.dcr.VipUrv7QH5bOKAzB_soEFtx.r',
#    'extra_img_urls': []},
#   {'id': 1316764,
#    'brand': {'id': 66629, 'name': 'Comfort'},
#    'kind': 'PRODUCT',
#    'related_to': None,
#    'buy_unit': 'UN',
#    'default_buy_unit': 'UN',
#    'variable_weight': False,
#    'currency': 'BRL',
#    'unit_conversion_rate': None,
#    'is_tobacco': False,
#    'purchasable': True,
#    'pricing': {'original_price': None,
#     'price': {'label': 'Preço', 'amount': 21.89, 'currency': 'BRL'},
#     'price_per_unit': None},
#    'price_per_unit': '',
#    'regulatory_fees': [],
#    'price': 21.89,
#    'original_price': None,
#    'label': 'Ver Promo',
#    'description_sections': [{'title': 'Ofertas Especiais com entrega grátis',
#      'text': 'Comprando R$280 em produtos Ofertas Especiais marcados com a promoção, você não paga a entrega.',
#      'type': 'DELIVERY'}],
#    'availability_status': 'AVAILABLE',
#    'nutritional_info': None,
#    'name': 'Refil de amaciante de roupas concentrado hipoalergênico',
#    'description': '.',
#    'package': '900ml',
#    'img_url': 'https://s.cornershopapp.com/product-images/1316764.jpg?versionId=xIjYKT2_uC_mYfUvRwrgkFhupsjlxilP',
#    'extra_img_urls': []},
#   {'id': 1191776,
#    'brand': {'id': 659, 'name': 'Downy'},
#    'kind': 'PRODUCT',
#    'related_to': None,
#    'buy_unit': 'UN',
#    'default_buy_unit': 'UN',
#    'variable_weight': None,
#    'currency': 'BRL',
#    'unit_conversion_rate': None,
#    'is_tobacco': False,
#    'purchasable': True,
#    'pricing': {'original_price': None,
#     'price': {'label': 'Preço', 'amount': 13.19, 'currency': 'BRL'},
#     'price_per_unit': None},
#    'price_per_unit': '',
#    'regulatory_fees': [],
#    'price': 13.19,
#    'original_price': None,
#    'label': None,
#    'description_sections': [],
#    'availability_status': 'AVAILABLE',
#    'nutritional_info': None,
#    'name': 'Amaciante de roupas concentrado Lírios do Campo',
#    'description': 'Amaciante concentrado que deixa as suas roupas perfumadas por mais tempo*! Downy Lírios do Campo possuí notas de perfume de rosas com um toque de flor de laranjeira, resultando em uma fragrância levemente adocicada. A fórmula de Downy possui microcápsulas de perfume especiais que se ativam com o toque, liberando perfume ao longo de todo o dia. Além disso, protege de odores desagradáveis como fumaça, fritura e suor, os impedindo de impregnar nas roupas**. Desta forma você se veste de perfume o dia todo. Por ser concentrado, 1.5L de Downy é equivalente a 6L de um amaciante diluído comum. Isso significa que ele rende até 66 lavagens. Para garantir um melhor uso, utilize apenas a quantidade de amaciante indicada na embalagem do produto. *Concentração de perfume depositada e liberada do tecido seco medida por métodos analíticos vs. amaciantes não concentrados **Baseado em provas realizadas com conjunto de odores representativos',
#    'package': '500g',
#    'img_url': 'https://s.cornershopapp.com/product-images/1191776.jpg?versionId=q9xhPumySv98bDUDJjB2Z3ylRyTGx.mE',
#    'extra_img_urls': []},
#   {'id': 1315722,
#    'brand': {'id': 66629, 'name': 'Comfort'},
#    'kind': 'PRODUCT',
#    'related_to': None,
#    'buy_unit': 'UN',
#    'default_buy_unit': 'UN',
#    'variable_weight': False,
#    'currency': 'BRL',
#    'unit_conversion_rate': None,
#    'is_tobacco': False,
#    'purchasable': True,
#    'pricing': {'original_price': None,
#     'price': {'label': 'Preço', 'amount': 31.69, 'currency': 'BRL'},
#     'price_per_unit': None},
#    'price_per_unit': '',
#    'regulatory_fees': [],
#    'price': 31.69,
#    'original_price': None,
#    'label': 'Ver Promo',
#    'description_sections': [{'title': 'Ofertas Especiais com entrega grátis',
#      'text': 'Comprando R$280 em produtos Ofertas Especiais marcados com a promoção, você não paga a entrega.',
#      'type': 'DELIVERY'}],
#    'availability_status': 'AVAILABLE',
#    'nutritional_info': None,
#    'name': 'Amaciante de roupas concentrado Puro Cuidado',
#    'description': 'Amaciante de roupas concentrado Puro Cuidado hipoalergênico óleo de argan',
#    'package': 'Garrafa 1,5l',
#    'img_url': 'https://s.cornershopapp.com/product-images/1315722.jpg?versionId=BUpObFsRuI9y0_pjFH_k_wcz8SbuKzV3',
#    'extra_img_urls': []},
#   {'id': 1191787,
#    'brand': {'id': 66629, 'name': 'Comfort'},
#    'kind': 'PRODUCT',
#    'related_to': None,
#    'buy_unit': 'UN',
#    'default_buy_unit': 'UN',
#    'variable_weight': False,
#    'currency': 'BRL',
#    'unit_conversion_rate': None,
#    'is_tobacco': False,
#    'purchasable': True,
#    'pricing': {'original_price': None,
#     'price': {'label': 'Preço', 'amount': 22.99, 'currency': 'BRL'},
#     'price_per_unit': None},
#    'price_per_unit': '',
#    'regulatory_fees': [],
#    'price': 22.99,
#    'original_price': None,
#    'label': None,
#    'description_sections': [],
#    'availability_status': 'AVAILABLE',
#    'nutritional_info': None,
#    'name': 'Amaciante de roupas concentrado intense com óleo de argan',
#    'description': None,
#    'package': '1l',
#    'img_url': 'https://s.cornershopapp.com/product-images/1191787.jpg?versionId=naRBJ3eQ9K8IbLw2228va.F2DWDMFZ0U',
#    'extra_img_urls': []},
#   {'id': 1191778,
#    'brand': {'id': 66629, 'name': 'Comfort'},
#    'kind': 'PRODUCT',
#    'related_to': None,
#    'buy_unit': 'UN',
#    'default_buy_unit': 'UN',
#    'variable_weight': False,
#    'currency': 'BRL',
#    'unit_conversion_rate': None,
#    'is_tobacco': False,
#    'purchasable': True,
#    'pricing': {'original_price': None,
#     'price': {'label': 'Preço', 'amount': 22.99, 'currency': 'BRL'},
#     'price_per_unit': None},
#    'price_per_unit': '',
#    'regulatory_fees': [],
#    'price': 22.99,
#    'original_price': None,
#    'label': None,
#    'description_sections': [],
#    'availability_status': 'AVAILABLE',
#    'nutritional_info': None,
#    'name': 'Amaciante de roupa concentrado cuidado intensivo com óleo de argan',
#    'description': None,
#    'package': '1l',
#    'img_url': 'https://s.cornershopapp.com/product-images/1191778.jpg?versionId=CiEyR3vsf_e94dRrpVOgcvCAViKbct.U',
#    'extra_img_urls': []},
#   {'id': 1191782,
#    'brand': {'id': 66629, 'name': 'Comfort'},
#    'kind': 'PRODUCT',
#    'related_to': None,
#    'buy_unit': 'UN',
#    'default_buy_unit': 'UN',
#    'variable_weight': None,
#    'currency': 'BRL',
#    'unit_conversion_rate': None,
#    'is_tobacco': False,
#    'purchasable': True,
#    'pricing': {'original_price': None,
#     'price': {'label': 'Preço', 'amount': 22.99, 'currency': 'BRL'},
#     'price_per_unit': None},
#    'price_per_unit': '',
#    'regulatory_fees': [],
#    'price': 22.99,
#    'original_price': None,
#    'label': None,
#    'description_sections': [],
#    'availability_status': 'AVAILABLE',
#    'nutritional_info': None,
#    'name': 'Amaciante de roupa concentrado Glamour',
#    'description': 'Amaciante concentrado Comfort, extrema maciez com exclusivo perfume envolvente. Cuidadosamente desenvolvido para deixar os tecidos macios e fáceis de passar e com um delicioso perfume encantador e duradouro.',
#    'package': '1l',
#    'img_url': 'https://s.cornershopapp.com/product-images/1191782.jpg?versionId=bMiuU2nXMS5R5FJjvCTvXYOYelXZORA6',
#    'extra_img_urls': []}]}

# %%
results[0]['search_result']['aisles'][0].keys()
# Out:
# dict_keys(['aisle_id', 'aisle_name', 'department_id', 'products'])

# %%
results[0]['search_result']['aisles'][0]['products']
# Out:
# [{'id': 1191812,
#   'brand': {'id': 73710, 'name': 'Ypê'},
#   'kind': 'PRODUCT',
#   'related_to': None,
#   'buy_unit': 'UN',
#   'default_buy_unit': 'UN',
#   'variable_weight': None,
#   'currency': 'BRL',
#   'unit_conversion_rate': None,
#   'is_tobacco': False,
#   'purchasable': True,
#   'pricing': {'original_price': {'label': 'ORIGINAL_PRICE',
#     'amount': 12.19,
#     'currency': 'BRL'},
#    'price': {'label': 'Preço', 'amount': 9.75, 'currency': 'BRL'},
#    'price_per_unit': None},
#   'price_per_unit': '',
#   'regulatory_fees': [],
#   'price': 9.75,
#   'original_price': '12.19',
#   'label': '20 % OFF',
#   'description_sections': [{'title': 'Amaciantes com 20% de desconto',
#     'text': 'Receba 20% de desconto em produtos marcados com a promoção. Verifique termos e condições.',
#     'type': 'DISCOUNT'}],
#   'availability_status': 'AVAILABLE',
#   'nutritional_info': None,
#   'name': 'Amaciante de roupas intenso',
#   'description': 'O Amaciante Ypê está com uma nova fórmula. Tem mais perfume e o toque mágico com Hidraceramidas, para roupas mais perfumadas e macias.',
#   'package': '2l',
#   'img_url': 'https://s.cornershopapp.com/product-images/1191812.png?versionId=07SCwy3Zm8h04uvoiIyqBZPApRhLepPT',
#   'extra_img_urls': []},
#  {'id': 1265631,
#   'brand': {'id': 73710, 'name': 'Ypê'},
#   'kind': 'PRODUCT',
#   'related_to': None,
#   'buy_unit': 'UN',
#   'default_buy_unit': 'UN',
#   'variable_weight': None,
#   'currency': 'BRL',
#   'unit_conversion_rate': None,
#   'is_tobacco': False,
#   'purchasable': True,
#   'pricing': {'original_price': {'label': 'ORIGINAL_PRICE',
#     'amount': 12.19,
#     'currency': 'BRL'},
#    'price': {'label': 'Preço', 'amount': 9.75, 'currency': 'BRL'},
#    'price_per_unit': None},
#   'price_per_unit': '',
#   'regulatory_fees': [],
#   'price': 9.75,
#   'original_price': '12.19',
#   'label': '20 % OFF',
#   'description_sections': [{'title': 'Amaciantes com 20% de desconto',
#     'text': 'Receba 20% de desconto em produtos marcados com a promoção. Verifique termos e condições.',
#     'type': 'DISCOUNT'}],
#   'availability_status': 'AVAILABLE',
#   'nutritional_info': None,
#   'name': 'Amaciante de roupas Aconchego',
#   'description': '',
#   'package': '2l',
#   'img_url': 'https://s.cornershopapp.com/product-images/1265631.png?versionId=c2eMNDfLXKs5ENLq1J8op8ftAxnRD0VH',
#   'extra_img_urls': []},
#  {'id': 1191769,
#   'brand': {'id': 659, 'name': 'Downy'},
#   'kind': 'PRODUCT',
#   'related_to': None,
#   'buy_unit': 'UN',
#   'default_buy_unit': 'UN',
#   'variable_weight': False,
#   'currency': 'BRL',
#   'unit_conversion_rate': None,
#   'is_tobacco': False,
#   'purchasable': True,
#   'pricing': {'original_price': None,
#    'price': {'label': 'Preço', 'amount': 25.59, 'currency': 'BRL'},
#    'price_per_unit': None},
#   'price_per_unit': '',
#   'regulatory_fees': [],
#   'price': 25.59,
#   'original_price': None,
#   'label': 'Ver Promo',
#   'description_sections': [{'title': 'Ofertas Especiais com entrega grátis',
#     'text': 'Comprando R$280 em produtos Ofertas Especiais marcados com a promoção, você não paga a entrega.',
#     'type': 'DELIVERY'}],
#   'availability_status': 'AVAILABLE',
#   'nutritional_info': None,
#   'name': 'Amaciante de roupas concentrado Brisa de Verão',
#   'description': 'Amaciante concentrado que deixa as suas roupas perfumadas por mais tempo*! Downy Brisa resultadas da combinação de flores brancas e cítricas e do frescor do herbal e âmbar. A fórmula de Downy possui microcápsulas de perfume especiais que se ativam com o toque, liberando perfume ao longo de todo o dia. Além disso, protege de odores desagradáveis como fumaça, fritura e suor, os impedindo de impregnar nas roupas**. Desta forma você se veste de perfume o dia todo. Por ser concentrado, 1.5L de Downy é equivalente a 6L de um amaciante diluído comum. Isso significa que ele rende até 66 lavagens. Para garantir um melhor uso, utilize apenas a quantidade de amaciante indicada na embalagem do produto. *Concentração de perfume depositada e liberada do tecido seco medida por métodos analíticos vs. amaciantes não concentrados **Baseado em provas realizadas com conjunto de odores representativos',
#   'package': '1l',
#   'img_url': 'https://s.cornershopapp.com/product-images/1191769.jpg?versionId=Hb1SFC8lD.f5cWUUwR.B.1LRVYDXepa9',
#   'extra_img_urls': []},
#  {'id': 1191770,
#   'brand': {'id': 659, 'name': 'Downy'},
#   'kind': 'PRODUCT',
#   'related_to': None,
#   'buy_unit': 'UN',
#   'default_buy_unit': 'UN',
#   'variable_weight': None,
#   'currency': 'BRL',
#   'unit_conversion_rate': None,
#   'is_tobacco': False,
#   'purchasable': True,
#   'pricing': {'original_price': {'label': 'ORIGINAL_PRICE',
#     'amount': 33.99,
#     'currency': 'BRL'},
#    'price': {'label': 'Preço', 'amount': 25.65, 'currency': 'BRL'},
#    'price_per_unit': None},
#   'price_per_unit': '',
#   'regulatory_fees': [],
#   'price': 25.65,
#   'original_price': '33.99',
#   'label': 'Ver Promo',
#   'description_sections': [{'title': 'Ofertas Especiais com entrega grátis',
#     'text': 'Comprando R$280 em produtos Ofertas Especiais marcados com a promoção, você não paga a entrega.',
#     'type': 'DELIVERY'},
#    {'title': 'Promoção Carrefour Hiper',
#     'text': 'Desconto exclusivo Carrefour Hiper',
#     'type': 'DISCOUNT'}],
#   'availability_status': 'AVAILABLE',
#   'nutritional_info': None,
#   'name': 'Amaciante de roupas concentrado Brisa de Verão',
#   'description': 'Amaciante concentrado que deixa as suas roupas perfumadas por mais tempo*! Downy Brisa resultadas da combinação de flores brancas e cítricas e do frescor do herbal e âmbar. A fórmula de Downy possui microcápsulas de perfume especiais que se ativam com o toque, liberando perfume ao longo de todo o dia. Além disso, protege de odores desagradáveis como fumaça, fritura e suor, os impedindo de impregnar nas roupas**. Desta forma você se veste de perfume o dia todo. Por ser concentrado, 1.5L de Downy é equivalente a 6L de um amaciante diluído comum. Isso significa que ele rende até 66 lavagens. Para garantir um melhor uso, utilize apenas a quantidade de amaciante indicada na embalagem do produto. *Concentração de perfume depositada e liberada do tecido seco medida por métodos analíticos vs. amaciantes não concentrados **Baseado em provas realizadas com conjunto de odores representativos',
#   'package': '1,5l',
#   'img_url': 'https://s.cornershopapp.com/product-images/1191770.jpg?versionId=2.ZgxKwn9gbRHrkKRxB1PhXo65UGUykU',
#   'extra_img_urls': []},
#  {'id': 1258284,
#   'brand': {'id': 73710, 'name': 'Ypê'},
#   'kind': 'PRODUCT',
#   'related_to': None,
#   'buy_unit': 'UN',
#   'default_buy_unit': 'UN',
#   'variable_weight': False,
#   'currency': 'BRL',
#   'unit_conversion_rate': None,
#   'is_tobacco': False,
#   'purchasable': True,
#   'pricing': {'original_price': {'label': 'ORIGINAL_PRICE',
#     'amount': 24.99,
#     'currency': 'BRL'},
#    'price': {'label': 'Preço', 'amount': 19.99, 'currency': 'BRL'},
#    'price_per_unit': None},
#   'price_per_unit': '',
#   'regulatory_fees': [],
#   'price': 19.99,
#   'original_price': '24.99',
#   'label': '20 % OFF',
#   'description_sections': [{'title': 'Amaciantes com 20% de desconto',
#     'text': 'Receba 20% de desconto em produtos marcados com a promoção. Verifique termos e condições.',
#     'type': 'DISCOUNT'},
#    {'title': 'Ofertas Especiais com entrega grátis',
#     'text': 'Comprando R$280 em produtos Ofertas Especiais marcados com a promoção, você não paga a entrega.',
#     'type': 'DELIVERY'}],
#   'availability_status': 'AVAILABLE',
#   'nutritional_info': None,
#   'name': 'Amaciante de roupas Aconchego',
#   'description': 'Embalagem promocional leve 5l e pague 4,5l',
#   'package': '5l',
#   'img_url': 'https://s.cornershopapp.com/product-images/1258284.jpg?versionId=47fyTmBcsh9UuJJDly51ZPBa2Bzw5HKQ',
#   'extra_img_urls': []},
#  {'id': 1313371,
#   'brand': {'id': 66629, 'name': 'Comfort'},
#   'kind': 'PRODUCT',
#   'related_to': None,
#   'buy_unit': 'UN',
#   'default_buy_unit': 'UN',
#   'variable_weight': None,
#   'currency': 'BRL',
#   'unit_conversion_rate': None,
#   'is_tobacco': False,
#   'purchasable': True,
#   'pricing': {'original_price': None,
#    'price': {'label': 'Preço', 'amount': 31.69, 'currency': 'BRL'},
#    'price_per_unit': None},
#   'price_per_unit': '',
#   'regulatory_fees': [],
#   'price': 31.69,
#   'original_price': None,
#   'label': 'Ver Promo',
#   'description_sections': [{'title': 'Ofertas Especiais com entrega grátis',
#     'text': 'Comprando R$280 em produtos Ofertas Especiais marcados com a promoção, você não paga a entrega.',
#     'type': 'DELIVERY'}],
#   'availability_status': 'AVAILABLE',
#   'nutritional_info': None,
#   'name': 'Amaciante concentrado para roupas cuidado intensivo óleo de argan',
#   'description': 'Rende 6,7 litros.',
#   'package': '1,5l',
#   'img_url': 'https://s.cornershopapp.com/product-images/1313371.jpg?versionId=9dnSRos4ZWVdhw3.wLqDDNABBJGnvgen',
#   'extra_img_urls': []},
#  {'id': 1258221,
#   'brand': {'id': 66629, 'name': 'Comfort'},
#   'kind': 'PRODUCT',
#   'related_to': None,
#   'buy_unit': 'UN',
#   'default_buy_unit': 'UN',
#   'variable_weight': None,
#   'currency': 'BRL',
#   'unit_conversion_rate': None,
#   'is_tobacco': False,
#   'purchasable': True,
#   'pricing': {'original_price': None,
#    'price': {'label': 'Preço', 'amount': 21.89, 'currency': 'BRL'},
#    'price_per_unit': None},
#   'price_per_unit': '',
#   'regulatory_fees': [],
#   'price': 21.89,
#   'original_price': None,
#   'label': 'Ver Promo',
#   'description_sections': [{'title': 'Ofertas Especiais com entrega grátis',
#     'text': 'Comprando R$280 em produtos Ofertas Especiais marcados com a promoção, você não paga a entrega.',
#     'type': 'DELIVERY'}],
#   'availability_status': 'AVAILABLE',
#   'nutritional_info': None,
#   'name': 'Refil de amaciante de roupas concentrado Original',
#   'description': 'Refil amaciante de roupa concentrado original intensivo cuidado essencial Confort.',
#   'package': '900ml',
#   'img_url': 'https://s.cornershopapp.com/product-images/1258221.jpg?versionId=9O.dcr.VipUrv7QH5bOKAzB_soEFtx.r',
#   'extra_img_urls': []},
#  {'id': 1316764,
#   'brand': {'id': 66629, 'name': 'Comfort'},
#   'kind': 'PRODUCT',
#   'related_to': None,
#   'buy_unit': 'UN',
#   'default_buy_unit': 'UN',
#   'variable_weight': False,
#   'currency': 'BRL',
#   'unit_conversion_rate': None,
#   'is_tobacco': False,
#   'purchasable': True,
#   'pricing': {'original_price': None,
#    'price': {'label': 'Preço', 'amount': 21.89, 'currency': 'BRL'},
#    'price_per_unit': None},
#   'price_per_unit': '',
#   'regulatory_fees': [],
#   'price': 21.89,
#   'original_price': None,
#   'label': 'Ver Promo',
#   'description_sections': [{'title': 'Ofertas Especiais com entrega grátis',
#     'text': 'Comprando R$280 em produtos Ofertas Especiais marcados com a promoção, você não paga a entrega.',
#     'type': 'DELIVERY'}],
#   'availability_status': 'AVAILABLE',
#   'nutritional_info': None,
#   'name': 'Refil de amaciante de roupas concentrado hipoalergênico',
#   'description': '.',
#   'package': '900ml',
#   'img_url': 'https://s.cornershopapp.com/product-images/1316764.jpg?versionId=xIjYKT2_uC_mYfUvRwrgkFhupsjlxilP',
#   'extra_img_urls': []},
#  {'id': 1191776,
#   'brand': {'id': 659, 'name': 'Downy'},
#   'kind': 'PRODUCT',
#   'related_to': None,
#   'buy_unit': 'UN',
#   'default_buy_unit': 'UN',
#   'variable_weight': None,
#   'currency': 'BRL',
#   'unit_conversion_rate': None,
#   'is_tobacco': False,
#   'purchasable': True,
#   'pricing': {'original_price': None,
#    'price': {'label': 'Preço', 'amount': 13.19, 'currency': 'BRL'},
#    'price_per_unit': None},
#   'price_per_unit': '',
#   'regulatory_fees': [],
#   'price': 13.19,
#   'original_price': None,
#   'label': None,
#   'description_sections': [],
#   'availability_status': 'AVAILABLE',
#   'nutritional_info': None,
#   'name': 'Amaciante de roupas concentrado Lírios do Campo',
#   'description': 'Amaciante concentrado que deixa as suas roupas perfumadas por mais tempo*! Downy Lírios do Campo possuí notas de perfume de rosas com um toque de flor de laranjeira, resultando em uma fragrância levemente adocicada. A fórmula de Downy possui microcápsulas de perfume especiais que se ativam com o toque, liberando perfume ao longo de todo o dia. Além disso, protege de odores desagradáveis como fumaça, fritura e suor, os impedindo de impregnar nas roupas**. Desta forma você se veste de perfume o dia todo. Por ser concentrado, 1.5L de Downy é equivalente a 6L de um amaciante diluído comum. Isso significa que ele rende até 66 lavagens. Para garantir um melhor uso, utilize apenas a quantidade de amaciante indicada na embalagem do produto. *Concentração de perfume depositada e liberada do tecido seco medida por métodos analíticos vs. amaciantes não concentrados **Baseado em provas realizadas com conjunto de odores representativos',
#   'package': '500g',
#   'img_url': 'https://s.cornershopapp.com/product-images/1191776.jpg?versionId=q9xhPumySv98bDUDJjB2Z3ylRyTGx.mE',
#   'extra_img_urls': []},
#  {'id': 1315722,
#   'brand': {'id': 66629, 'name': 'Comfort'},
#   'kind': 'PRODUCT',
#   'related_to': None,
#   'buy_unit': 'UN',
#   'default_buy_unit': 'UN',
#   'variable_weight': False,
#   'currency': 'BRL',
#   'unit_conversion_rate': None,
#   'is_tobacco': False,
#   'purchasable': True,
#   'pricing': {'original_price': None,
#    'price': {'label': 'Preço', 'amount': 31.69, 'currency': 'BRL'},
#    'price_per_unit': None},
#   'price_per_unit': '',
#   'regulatory_fees': [],
#   'price': 31.69,
#   'original_price': None,
#   'label': 'Ver Promo',
#   'description_sections': [{'title': 'Ofertas Especiais com entrega grátis',
#     'text': 'Comprando R$280 em produtos Ofertas Especiais marcados com a promoção, você não paga a entrega.',
#     'type': 'DELIVERY'}],
#   'availability_status': 'AVAILABLE',
#   'nutritional_info': None,
#   'name': 'Amaciante de roupas concentrado Puro Cuidado',
#   'description': 'Amaciante de roupas concentrado Puro Cuidado hipoalergênico óleo de argan',
#   'package': 'Garrafa 1,5l',
#   'img_url': 'https://s.cornershopapp.com/product-images/1315722.jpg?versionId=BUpObFsRuI9y0_pjFH_k_wcz8SbuKzV3',
#   'extra_img_urls': []},
#  {'id': 1191787,
#   'brand': {'id': 66629, 'name': 'Comfort'},
#   'kind': 'PRODUCT',
#   'related_to': None,
#   'buy_unit': 'UN',
#   'default_buy_unit': 'UN',
#   'variable_weight': False,
#   'currency': 'BRL',
#   'unit_conversion_rate': None,
#   'is_tobacco': False,
#   'purchasable': True,
#   'pricing': {'original_price': None,
#    'price': {'label': 'Preço', 'amount': 22.99, 'currency': 'BRL'},
#    'price_per_unit': None},
#   'price_per_unit': '',
#   'regulatory_fees': [],
#   'price': 22.99,
#   'original_price': None,
#   'label': None,
#   'description_sections': [],
#   'availability_status': 'AVAILABLE',
#   'nutritional_info': None,
#   'name': 'Amaciante de roupas concentrado intense com óleo de argan',
#   'description': None,
#   'package': '1l',
#   'img_url': 'https://s.cornershopapp.com/product-images/1191787.jpg?versionId=naRBJ3eQ9K8IbLw2228va.F2DWDMFZ0U',
#   'extra_img_urls': []},
#  {'id': 1191778,
#   'brand': {'id': 66629, 'name': 'Comfort'},
#   'kind': 'PRODUCT',
#   'related_to': None,
#   'buy_unit': 'UN',
#   'default_buy_unit': 'UN',
#   'variable_weight': False,
#   'currency': 'BRL',
#   'unit_conversion_rate': None,
#   'is_tobacco': False,
#   'purchasable': True,
#   'pricing': {'original_price': None,
#    'price': {'label': 'Preço', 'amount': 22.99, 'currency': 'BRL'},
#    'price_per_unit': None},
#   'price_per_unit': '',
#   'regulatory_fees': [],
#   'price': 22.99,
#   'original_price': None,
#   'label': None,
#   'description_sections': [],
#   'availability_status': 'AVAILABLE',
#   'nutritional_info': None,
#   'name': 'Amaciante de roupa concentrado cuidado intensivo com óleo de argan',
#   'description': None,
#   'package': '1l',
#   'img_url': 'https://s.cornershopapp.com/product-images/1191778.jpg?versionId=CiEyR3vsf_e94dRrpVOgcvCAViKbct.U',
#   'extra_img_urls': []},
#  {'id': 1191782,
#   'brand': {'id': 66629, 'name': 'Comfort'},
#   'kind': 'PRODUCT',
#   'related_to': None,
#   'buy_unit': 'UN',
#   'default_buy_unit': 'UN',
#   'variable_weight': None,
#   'currency': 'BRL',
#   'unit_conversion_rate': None,
#   'is_tobacco': False,
#   'purchasable': True,
#   'pricing': {'original_price': None,
#    'price': {'label': 'Preço', 'amount': 22.99, 'currency': 'BRL'},
#    'price_per_unit': None},
#   'price_per_unit': '',
#   'regulatory_fees': [],
#   'price': 22.99,
#   'original_price': None,
#   'label': None,
#   'description_sections': [],
#   'availability_status': 'AVAILABLE',
#   'nutritional_info': None,
#   'name': 'Amaciante de roupa concentrado Glamour',
#   'description': 'Amaciante concentrado Comfort, extrema maciez com exclusivo perfume envolvente. Cuidadosamente desenvolvido para deixar os tecidos macios e fáceis de passar e com um delicioso perfume encantador e duradouro.',
#   'package': '1l',
#   'img_url': 'https://s.cornershopapp.com/product-images/1191782.jpg?versionId=bMiuU2nXMS5R5FJjvCTvXYOYelXZORA6',
#   'extra_img_urls': []}]

# %%
len(results[0]['search_result']['aisles'][0]['products'])
# Out:
# 13

# %% [markdown]
# Temos mais 13 objetos dentro de `products`

# %%
results[0]['search_result']['aisles'][0]['products'][11]
# Out:
# {'id': 1191778,
#  'brand': {'id': 66629, 'name': 'Comfort'},
#  'kind': 'PRODUCT',
#  'related_to': None,
#  'buy_unit': 'UN',
#  'default_buy_unit': 'UN',
#  'variable_weight': False,
#  'currency': 'BRL',
#  'unit_conversion_rate': None,
#  'is_tobacco': False,
#  'purchasable': True,
#  'pricing': {'original_price': None,
#   'price': {'label': 'Preço', 'amount': 22.99, 'currency': 'BRL'},
#   'price_per_unit': None},
#  'price_per_unit': '',
#  'regulatory_fees': [],
#  'price': 22.99,
#  'original_price': None,
#  'label': None,
#  'description_sections': [],
#  'availability_status': 'AVAILABLE',
#  'nutritional_info': None,
#  'name': 'Amaciante de roupa concentrado cuidado intensivo com óleo de argan',
#  'description': None,
#  'package': '1l',
#  'img_url': 'https://s.cornershopapp.com/product-images/1191778.jpg?versionId=CiEyR3vsf_e94dRrpVOgcvCAViKbct.U',
#  'extra_img_urls': []}

# %%
results[0]['search_result']['aisles'][0]['products'][1]
# Out:
# {'id': 1265631,
#  'brand': {'id': 73710, 'name': 'Ypê'},
#  'kind': 'PRODUCT',
#  'related_to': None,
#  'buy_unit': 'UN',
#  'default_buy_unit': 'UN',
#  'variable_weight': None,
#  'currency': 'BRL',
#  'unit_conversion_rate': None,
#  'is_tobacco': False,
#  'purchasable': True,
#  'pricing': {'original_price': {'label': 'ORIGINAL_PRICE',
#    'amount': 12.19,
#    'currency': 'BRL'},
#   'price': {'label': 'Preço', 'amount': 9.75, 'currency': 'BRL'},
#   'price_per_unit': None},
#  'price_per_unit': '',
#  'regulatory_fees': [],
#  'price': 9.75,
#  'original_price': '12.19',
#  'label': '20 % OFF',
#  'description_sections': [{'title': 'Amaciantes com 20% de desconto',
#    'text': 'Receba 20% de desconto em produtos marcados com a promoção. Verifique termos e condições.',
#    'type': 'DISCOUNT'}],
#  'availability_status': 'AVAILABLE',
#  'nutritional_info': None,
#  'name': 'Amaciante de roupas Aconchego',
#  'description': '',
#  'package': '2l',
#  'img_url': 'https://s.cornershopapp.com/product-images/1265631.png?versionId=c2eMNDfLXKs5ENLq1J8op8ftAxnRD0VH',
#  'extra_img_urls': []}

# %%
results[0]['search_result']['aisles'][0]['products'][12]
# Out:
# {'id': 1191782,
#  'brand': {'id': 66629, 'name': 'Comfort'},
#  'kind': 'PRODUCT',
#  'related_to': None,
#  'buy_unit': 'UN',
#  'default_buy_unit': 'UN',
#  'variable_weight': None,
#  'currency': 'BRL',
#  'unit_conversion_rate': None,
#  'is_tobacco': False,
#  'purchasable': True,
#  'pricing': {'original_price': None,
#   'price': {'label': 'Preço', 'amount': 22.99, 'currency': 'BRL'},
#   'price_per_unit': None},
#  'price_per_unit': '',
#  'regulatory_fees': [],
#  'price': 22.99,
#  'original_price': None,
#  'label': None,
#  'description_sections': [],
#  'availability_status': 'AVAILABLE',
#  'nutritional_info': None,
#  'name': 'Amaciante de roupa concentrado Glamour',
#  'description': 'Amaciante concentrado Comfort, extrema maciez com exclusivo perfume envolvente. Cuidadosamente desenvolvido para deixar os tecidos macios e fáceis de passar e com um delicioso perfume encantador e duradouro.',
#  'package': '1l',
#  'img_url': 'https://s.cornershopapp.com/product-images/1191782.jpg?versionId=bMiuU2nXMS5R5FJjvCTvXYOYelXZORA6',
#  'extra_img_urls': []}

# %% [markdown]
# Parece que temos uma diferenciação do produto, ou seja, são 13 opções pelo mesmo tipo de produto (amaciante) com diferentes marcas ou mesmo da mesma marca mas de uma edição diferente.
#
# Aqui é um ponto importante pois se queremos comparar preços de um mesmo produto como 'amaciante':
#
# #### Quero saber aonde é mais barato
# preço/mercado/promoção/marca

# %% [markdown]
# _______________

# %%
data = json_file['results'][7]
# Exemplo de extração de informações
store_name = data['store']['name']
store_description = data['store']['description']
search_term = data['search_result']['search_term']
aisles = data['search_result']['aisles']

print(f"Nome da loja: {store_name}")
print(f"Descrição da loja: {store_description}")
print(f"Termo de busca: {search_term}")
print("Aisles:")
for aisle in aisles:
    aisle_name = aisle['aisle_name']
    print(f"  - Nome do corredor: {aisle_name}")
    products = aisle['products']
    for product in products:
        product_name = product['name']
        product_price = product['pricing']['price']['amount']
        print(f"    * Produto: {product_name} - Preço: R$ {product_price}")
# Out:
# Nome da loja: Farmácia Preço Popular
# Descrição da loja: Farmácia Preço Popular, variedade de medicamentos e produtos para bem estar.
# Termo de busca: amaciante
# Aisles:
#   - Nome do corredor: Cuidados faciais
#     * Produto: Vaselina sólida - Preço: R$ 11.29
