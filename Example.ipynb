# %%
from src.get_json import get_and_create
term = 'sabonete'  # replace with your term
code = 88010560  # replace with your code
country = 'BR'  # replace with your country
base_dir = r'C:\Users\Eric\Documents\___Portfolio\cornershop'

json_file = get_and_create(term, code, country, base_dir)

json_file[0]
# Out:
# {'date': '07-06-2023',
#  'aisle_name': 'Sabonetes',
#  'product_name': 'Sabonete com glicerina Botanicals buquê de jasmim',
#  'brand': 'Lux',
#  'price': 2.95,
#  'package': 'Barra 85g',
#  'store_name': 'Atacadão',
#  'store_city': 'FLN',
#  'search_term': 'sabonete'}

# %%
import pandas as pd
pd.DataFrame(json_file)
# Out:
#            date aisle_name                                       product_name  \
# 0    07-06-2023  Sabonetes  Sabonete com glicerina Botanicals buquê de jasmim
# 1    07-06-2023  Sabonetes         Sabonete em barra flor de maçã e framboesa
# 2    07-06-2023  Sabonetes         Sabonete hidratante com proteínas do leite
# 3    07-06-2023  Sabonetes     Sabonete glicerinado Botanicals orquídea negra
# 4    07-06-2023  Sabonetes            Sabonete hidratante com lavanda & óleos
# ..          ...        ...                                                ...
# 205  07-06-2023  Sabonetes                         Sabonete cremoso mandacaru
# 206  07-06-2023  Sabonetes                      Sabonete líquido água de coco
# 207  07-06-2023  Sabonetes     Sabonete perfumado Au Brésil flor de carambola
# 208  07-06-2023  Sabonetes                     Sabonete perfumado capim-limão
# 209  07-06-2023  Sabonetes                       Sabonete líquido capim-limão
#
#                     brand  price          package            store_name  \
# 0                     Lux   2.95        Barra 85g              Atacadão
# 1             Flor De Ypê   1.44              85g              Atacadão
# 2                   Nivea   2.99              85g              Atacadão
# 3                     Lux   2.95              85g              Atacadão
# 4                   Nivea   2.99              85g              Atacadão
# ..                    ...    ...              ...                   ...
# 205  L'Occitane Au Brésil  14.97        Embalagem  L'Occitane au Brésil
# 206  L'Occitane Au Brésil  80.30   Embalagem 300g  L'Occitane au Brésil
# 207            L'Occitane  14.97              75g  L'Occitane au Brésil
# 208  L'Occitane Au Brésil  20.00  Embalagem  100g  L'Occitane au Brésil
# 209  L'Occitane Au Brésil  50.15   Embalagem 300g  L'Occitane au Brésil
#
#     store_city search_term
# 0          FLN    sabonete
# 1          FLN    sabonete
# 2          FLN    sabonete
# 3          FLN    sabonete
# 4          FLN    sabonete
# ..         ...         ...
# 205        FLN    sabonete
# 206        FLN    sabonete
# 207        FLN    sabonete
# 208        FLN    sabonete
# 209        FLN    sabonete
#
# [210 rows x 9 columns]
