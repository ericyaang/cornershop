# %%
from src.get_json import get_and_create

json = get_and_create('arroz', 88010560, 'BR', './data')
json
# Out:
# [{'date': '07-06-2023',
#   'aisle_name': 'Arroz e grãos',
#   'product_name': 'Arroz branco longo fino tipo 1',
#   'brand': 'Tio João',
#   'price': 5.59,
#   'package': '1kg',
#   'store_name': 'BIG by Carrefour',
#   'store_city': 'FLN',
#   'search_term': 'arroz'},
#  {'date': '07-06-2023',
#   'aisle_name': 'Arroz e grãos',
#   'product_name': 'Arroz polido longo fino tipo 1',
#   'brand': 'Camil',
#   'price': 24.59,
#   'package': '5kg',
#   'store_name': 'BIG by Carrefour',
#   'store_city': 'FLN',
#   'search_term': 'arroz'},
#  {'date': '07-06-2023',
#   'aisle_name': 'Arroz e grãos',
#   'product_name': 'Arroz polido longo fino tipo 1',
#   'brand': 'Camil',
#   'price': 5.59,
#   'package': '1kg',
#   'store_name': 'BIG by Carrefour',
#   'store_city': 'FLN',
#   'search_term': 'arroz'},
#  {'date': '07-06-2023',
#   'aisle_name': 'Arroz e grãos',
#   'product_name': 'Arroz branco longo-fino tipo 1',
#   'brand': 'Prato Fino',
#   'price': 6.59,
#   'package': '1kg',
# ...

# %%
import pandas as pd
pd.DataFrame(json)
# Out:
#            date                      aisle_name  \
# 0    07-06-2023                   Arroz e grãos
# 1    07-06-2023                   Arroz e grãos
# 2    07-06-2023                   Arroz e grãos
# 3    07-06-2023                   Arroz e grãos
# 4    07-06-2023                   Arroz e grãos
# ..          ...                             ...
# 143  07-06-2023                Cuidados faciais
# 144  07-06-2023         Vitaminas e suplementos
# 145  07-06-2023                Cuidados faciais
# 146  07-06-2023                Cuidados faciais
# 147  07-06-2023  Cremes e tratamentos corporais
#
#                                           product_name       brand   price  \
# 0                       Arroz branco longo fino tipo 1    Tio João    5.59
# 1                       Arroz polido longo fino tipo 1       Camil   24.59
# 2                       Arroz polido longo fino tipo 1       Camil    5.59
# 3                       Arroz branco longo-fino tipo 1  Prato Fino    6.59
# ...
