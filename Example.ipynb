# %% [markdown]
# # Demonstração

# %%
from src.get_json import get_and_create
term = 'sabonete'  # replace with your term
code = 88010560  # replace with your code
country = 'BR'  # replace with your country
base_dir = r'C:\Users\Eric\Documents\___Portfolio\cornershop'

# get and save product info
json_file = get_and_create(term, code, country, base_dir)

# Look at the first sample
json_file[0]
# Out:
# Fetching product data...
# Saving data as JSON: C:\Users\Eric\Documents\___Portfolio\cornershop\data\sabonete_88010560_20230608_101059.json
# Data saved successfully.
# {'date': '08-06-2023',
#  'aisle_name': 'Sabonetes',
#  'product_name': 'Sabonete com glicerina Botanicals buquê de jasmim',
#  'brand': 'Lux',
#  'price': 2.95,
#  'package': 'Barra 85g',
#  'store_name': 'Atacadão',
#  'store_city': 'FLN',
#  'search_term': 'sabonete'}

# %%
import pandas as pd
# overview as a dataframe
pd.DataFrame(json_file)
# Out:
#            date aisle_name                                       product_name  \
# 0    08-06-2023  Sabonetes  Sabonete com glicerina Botanicals buquê de jasmim
# 1    08-06-2023  Sabonetes         Sabonete em barra flor de maçã e framboesa
# 2    08-06-2023  Sabonetes         Sabonete hidratante com proteínas do leite
# 3    08-06-2023  Sabonetes     Sabonete glicerinado Botanicals orquídea negra
# 4    08-06-2023  Sabonetes            Sabonete hidratante com lavanda & óleos
# ..          ...        ...                                                ...
# 208  08-06-2023  Sabonetes                         Sabonete cremoso mandacaru
# 209  08-06-2023  Sabonetes                      Sabonete líquido água de coco
# 210  08-06-2023  Sabonetes     Sabonete perfumado Au Brésil flor de carambola
# 211  08-06-2023  Sabonetes                     Sabonete perfumado capim-limão
# 212  08-06-2023  Sabonetes                       Sabonete líquido capim-limão
#
# ...

# %% [markdown]
# ## Criando listas de termos possíveis para produtos de supermercado

# %%
frutas = [
    'Maçã',
    'Banana',
    'Laranja',
    'Uva',
    'Morango',
    'Abacaxi',
    'Melancia',
    'Pera',
    'Manga',
    'Limão',
    'Cereja',
    'Kiwi',
    'Pêssego',
    'Ameixa',
    'Caju',
    'Pitaya',
    'Framboesa',
    'Goiaba',
    'Tangerina',
    'Melão',
    'Mirtilo',
    'Caqui',
    'Jabuticaba',
    'Physalis',
    'Carambola',
    'Cereja-do-Rio-Grande',
    'Coco',
    'Abacate',
    'Jaca',
    'Maracujá',
    'Amora',
    'Groselha',
    'Romã',
    'Lichia',
    'Açaí',
    'Carambola',
    'Pitanga',
    'Fruta-do-conde',
    'Cajá',
    'Graviola',
    'Figo',
    'Pêssego',
    'Caqui',
    'Nectarina',
    'Kiwano',
    'Melão-de-são-caetano',
    'Fruta-de-conde',
    'Coco-verde',
    'Mamão',
    'Cajá-manga',
    'Pitomba',
    'Cacau',
    'Pupunha',
    'Lima',
    'Fruta-pão',
    'Tamarindo',
    'Uxi',
    'Jambo',
    'Bacuri',
    'Tamarillo',
]

carnes = [
    'Filé Mignon',
    'Frango',
    'Picanha',
    'Alcatra',
    'Linguiça',
    'Peixe',
    'Costela',
    'Carne Moída',
    'Camarão',
    'Salmão',
    'Lombo',
    'Porco',
    'Cordeiro',
    'Coelho',
    'Pato',
    'Bife de Contrafilé',
    'Tilápia',
    'Bacalhau',
    'Atum',
    'Paleta de Porco',
    'Frango à Passarinho',
    'Miolo de Alcatra',
    'Maminha',
    'Pernil',
    'Filé de Peixe',
    'Toucinho',
    'Picanha Suína',
    'Linguiça Calabresa',
    'Lombo de Porco',
    'Salsicha',
    'Peru',
    'Costeleta de Porco',
    'Frango Desossado',
    'Bisteca',
    'Carne de Sol',
    'Bife de Chorizo',
    'Picanha Argentina',
    'Frango em Pedaços',
    'Filé de Tilápia',
    'Filé de Frango',
    'Linguiça Toscana',
    'Lagarto',
    'Capa de Filé',
    'Filé de Salmão',
    'Anchova',
    'Contrafilé de Porco',
    'Picanha Maturada',
    'Carne de Siri',
    'Costelinha de Porco',
    'Peito de Peru',
    'Peito de Frango',
    'Linguiça de Frango',
    'Picanha de Porco',
    'Filé de Merluza',
    'Lula',
    'Carne Seca',
    'Coxa de Frango',
    'Sardinha',
    'Barriga de Porco',
    'Lombo Suíno',
    'Carne de Caranguejo',
    'Coração de Frango',
]

congelados = [
    'Pizza',
    'Hambúrguer',
    'Lasanha',
    'Batata Frita',
    'Sorvete',
    'Peixe empanado',
    'Nuggets de frango',
    'Pão de queijo',
    'Coxinha',
    'Pastel',
    'Croissant',
    'Empanada',
    'Torta',
    'Esfiha',
    'Camarão empanado',
    'Pão de batata recheado',
    'Brigadeiro',
    'Churros',
    'Mandioca frita',
    'Coxinha de frango',
    'Empada',
    'Kibe',
    'Bolinho de bacalhau',
    'Bolinho de queijo',
    'Rissole',
    'Creme de açaí',
    'Pudim',
    'Massa para lasanha',
    'Sorvete de creme',
    'Sorvete de chocolate',
    'Sorvete de morango',
    'Sorvete de baunilha',
    'Sorvete de flocos',
    'Sorvete de maracujá',
    'Sorvete de limão',
    'Sorvete de uva',
    'Sorvete de abacaxi',
    'Sorvete de coco',
    'Coxinha de frango com catupiry',
    'Empadão',
    'Torta salgada',
    'Quiche',
    'Bolinho de carne',
    'Bolinho de aipim com carne seca',
    'Bolinho de feijoada',
    'Bolinho de camarão',
    'Rocambole',
    'Bolinho de queijo com presunto',
    'Pão de queijo com requeijão',
    'Pizza de calabresa',
    'Pizza de mussarela',
    'Pizza de frango com catupiry',
    'Pizza de margherita',
    'Pizza de peperoni',
    'Pizza de quatro queijos',
    'Pizza de portuguesa',
    'Pizza de bacon',
    'Pizza de banana com chocolate',
    'Pizza de abacaxi com presunto',
]

laticinios = [
    'Leite',
    'Queijo',
    'Iogurte',
    'Manteiga',
    'Requeijão',
    'Nata',
    'Coalhada',
    'Creme de Leite',
    'Leite Condensado',
    'Sorvete',
    'Iogurte Grego',
    'Queijo Mussarela',
    'Queijo Parmesão',
    'Queijo Provolone',
    'Queijo Minas',
    'Queijo Gorgonzola',
    'Queijo Prato',
    'Queijo Cottage',
    'Queijo Roquefort',
    'Queijo Ricota',
    'Queijo Brie',
    'Queijo Camembert',
    'Queijo Cheddar',
    'Queijo Gouda',
    'Queijo Emmental',
    'Queijo Reino',
    'Queijo Edam',
    'Queijo Feta',
    'Leite de Coco',
    'Leite de Amêndoas',
    'Leite de Aveia',
    'Leite de Soja',
    'Leite de Arroz',
    'Iogurte Natural',
    'Iogurte de Morango',
    'Iogurte de Frutas Vermelhas',
    'Iogurte de Banana',
    'Iogurte de Baunilha',
    'Iogurte de Cereja',
    'Iogurte de Abacaxi',
    'Iogurte de Manga',
    'Manteiga com Sal',
    'Manteiga sem Sal',
    'Requeijão Cremoso',
    'Requeijão Light',
    'Coalhada Seca',
    'Coalhada Tradicional',
    'Creme de Leite Fresco',
    'Creme de Leite de Caixinha',
    'Leite Condensado Tradicional',
    'Leite Condensado Light',
    'Sorvete de Chocolate',
    'Sorvete de Baunilha',
    'Sorvete de Morango',
    'Sorvete de Creme',
    'Sorvete de Flocos',
    'Sorvete de Pistache',
    'Sorvete de Limão',
    'Sorvete de Uva',
    'Sorvete de Abacaxi',
    'Sorvete de Coco',
]

limpeza = [
    'Detergente',
    'Sabão em pó',
    'Desinfetante',
    'Amaciante',
    'Água sanitária',
    'Limpador multiuso',
    'Esponja de limpeza',
    'Pano de limpeza',
    'Lustra-móveis',
    'Limpa-vidros',
    'Limpa-banheiro',
    'Desengordurante',
    'Alvejante',
    'Sabão líquido',
    'Sabonete',
    'Sabão em barra',
    'Removedor de manchas',
    'Álcool',
    'Desodorizador de ambiente',
    'Saco de lixo',
    'Inseticida',
    'Vassoura',
    'Rodo',
    'Balde',
    'Pá de lixo',
    'Aspirador de pó',
    'Panos de chão',
    'Pano de prato',
    'Pano de microfibra',
    'Escova de limpeza',
    'Escova sanitária',
    'Luvas de limpeza',
    'Mop',
    'Saco de aspirador de pó',
    'Bucha de limpeza',
    'Escova de cerdas',
    'Flanela',
    'Rodo mágico',
    'Desengripante',
    'Cera para piso',
    'Inseticida em aerossol',
    'Limpador de metais',
    'Desodorizador de geladeira',
    'Saco para aspirador de pó',
    'Fósforo',
    'Rolo adesivo para limpeza',
    'Odorizador de ambiente',
    'Escova para limpeza de roupas',
    'Vassoura de piaçava',
    'Escova para limpeza de carpete',
    'Escova para limpeza de azulejo',
    'Vassoura mágica',
    'Escova de limpeza de vasos sanitários',
    'Balde espremedor',
    'Cesto para lixo',
    'Limpador para fogão',
    'Rolo adesivo para remoção de pelos',
]

cereais = [
    'Arroz',
    'Feijão',
    'Milho',
    'Trigo',
    'Aveia',
    'Cevada',
    'Granola',
    'Farinha de Trigo',
    'Farinha de Milho',
    'Farinha de Aveia',
    'Flocos de Milho',
    'Flocos de Arroz',
    'Fubá',
    'Quinoa',
    'Semente de Chia',
    'Semente de Linhaça',
    'Macarrão',
    'Massa de Lasanha',
    'Cuscuz',
    'Pão de Forma',
    'Pão de Centeio',
    'Pão Integral',
    'Pão Francês',
    'Cereal Matinal',
    'Biscoito de Arroz',
    'Biscoito de Milho',
    'Biscoito de Aveia',
    'Biscoito de Maisena',
    'Barra de Cereal',
    'Farofa Pronta',
    'Granola',
    'Pipoca',
    'Tapioca',
    'Farinha de Mandioca',
    'Bolacha de Água e Sal',
    'Bolacha Recheada',
    'Bolacha de Maisena',
    'Bolacha de Chocolate',
    'Bolacha de Aveia',
    'Pão Sírio',
    'Pão de Queijo',
    'Pão de Hambúrguer',
    'Pão de Hot Dog',
    'Pão Integral',
    'Cereal Infantil',
    'Farelo de Aveia',
    'Farelo de Trigo',
    'Farelo de Arroz',
    'Biscoito de Polvilho',
    'Torrada',
    'Rosquinha',
    'Cereal de Arroz',
    'Cereal de Milho',
    'Cereal de Trigo',
    'Cereal de Aveia',
]

higiene_pessoal = [
    'Shampoo',
    'Condicionador',
    'Sabonete',
    'Creme Dental',
    'Desodorante',
    'Papel Higiênico',
    'Lenço de Papel',
    'Escova de Dentes',
    'Fio Dental',
    'Enxaguante Bucal',
    'Absorvente',
    'Protetor Diário',
    'Creme Hidratante',
    'Loção Corporal',
    'Perfume',
    'Hidratante Labial',
    'Gel de Banho',
    'Desodorante Roll-on',
    'Desodorante Aerosol',
    'Desodorante Creme',
    'Desodorante Stick',
    'Cotonete',
    'Algodão',
    'Barbeador',
    'Espuma de Barbear',
    'Gel para Cabelo',
    'Cera para Cabelo',
    'Máscara Facial',
    'Sabonete Líquido',
    'Sabonete Íntimo',
    'Loção Pós-barba',
    'Tônico Facial',
    'Escova de Cabelo',
    'Pente',
    'Pinça',
    'Creme Depilatório',
    'Desodorante Íntimo',
    'Hastes Flexíveis',
    'Curativo',
    'Antisséptico Bucal',
    'Esmalte',
    'Removedor de Esmalte',
    'Acetona',
    'Lixa de Unha',
    'Hidratante para Mãos',
    'Hidratante para Pés',
    'Creme para Assaduras',
    'Absorvente Noturno',
    'Sabonete Íntimo Masculino',
    'Desodorante Íntimo Masculino',
    'Desodorante Íntimo Feminino',
    'Creme de Barbear',
    'Colônia',
    'Perfume',
    'Máscara de Cílios',
    'Batom',
    'Base',
    'Corretivo',
    'Blush',
]

limpeza = [
    'Detergente',
    'Sabão em Pó',
    'Amaciante',
    'Água Sanitária',
    'Desinfetante',
    'Limpador Multiuso',
    'Esponja',
    'Pano de Limpeza',
    'Limpador de Vidros',
    'Lustra Móveis',
    'Limpa Banheiro',
    'Limpa Forno',
    'Limpa Carpete',
    'Limpa Piso',
    'Saco de Lixo',
    'Inseticida',
    'Repelente',
    'Vassoura',
    'Rodo',
    'Mop',
    'Pá de Lixo',
    'Balde',
    'Escova de Limpeza',
    'Pano de Chão',
    'Pano de Prato',
    'Pano de Pia',
    'Limpador Perfumado',
    'Limpador de Alumínio',
    'Limpador de Inox',
    'Limpador de Azulejo',
    'Limpador de Granito',
    'Limpador de Mármore',
    'Limpador de Aço Inox',
    'Limpa Vidros',
    'Saponáceo',
    'Limpa Carpete',
    'Limpa Estofados',
    'Limpa Couro',
    'Limpa Vidro',
    'Limpa Pisos',
    'Desengordurante',
    'Tira Manchas',
    'Pasta de Limpeza',
    'Cera Líquida',
    'Polidor de Móveis',
    'Cera em Pasta',
    'Cera em Gel',
    'Limpa Rejuntes',
    'Removedor de Ferrugem',
    'Água de Passar',
    'Limpador de Janelas',
    'Água de Passar',
    'Tira-limo',
    'Tira-mofo',
    'Odorizador de Ambiente',
    'Sabão Líquido',
    'Sabão em Barra',
    'Cloro',
    'Amaciante Concentrado',
    'Amaciante para Roupas',
    'Amaciante Perfumado',
    'Lustra Móveis Aerosol',
    'Lustra Móveis em Gel',
    'Lustra Móveis em Spray',
    'Limpador de Banheiro',
    'Limpador de Cozinha',
]

# Crie uma lista final contendo todas as categorias
supermercado = [frutas, carnes, laticinios, cereais, higiene_pessoal, limpeza]

# Verifique o número total de produtos
numero_produtos = sum(len(categoria) for categoria in supermercado)
print("Número total de produtos:", numero_produtos)
# Out:
# Número total de produtos: 363

# %% [markdown]
# ## Extraindo e Salvando

# %%
supermercado = [frutas, carnes, laticinios, cereais, higiene_pessoal, limpeza]

for categoria in supermercado:
    for item in categoria:
        fruta_data = get_and_create(item, code, country, base_dir)
# Out:
# Fetching product data...
# Saving data as JSON: C:\Users\Eric\Documents\___Portfolio\cornershop\data\Maçã_88010560_20230609_223252.json
# Data saved successfully.
# Fetching product data...
# Saving data as JSON: C:\Users\Eric\Documents\___Portfolio\cornershop\data\Banana_88010560_20230609_223255.json
# Data saved successfully.
# Fetching product data...
# Saving data as JSON: C:\Users\Eric\Documents\___Portfolio\cornershop\data\Laranja_88010560_20230609_223259.json
# Data saved successfully.
# Fetching product data...
# Saving data as JSON: C:\Users\Eric\Documents\___Portfolio\cornershop\data\Uva_88010560_20230609_223303.json
# Data saved successfully.
# Fetching product data...
# Saving data as JSON: C:\Users\Eric\Documents\___Portfolio\cornershop\data\Morango_88010560_20230609_223307.json
# Data saved successfully.
# Fetching product data...
# Saving data as JSON: C:\Users\Eric\Documents\___Portfolio\cornershop\data\Abacaxi_88010560_20230609_223310.json
# Data saved successfully.
# ...

# %% [markdown]
# ## Carregando todos os dados do diretório `./data/` em um único dataframe

# %%
import glob
import pandas as pd
def read_json_files_as_dataframe(directory):
    """
    Read all JSON files from a directory and combine them into a single DataFrame.

    Args:
        directory (str): The path to the directory containing the JSON files.

    Returns:
        pd.DataFrame: The resulting DataFrame that combines all the JSON files.

    """
    file_paths = glob.glob(f"{directory}/*.json")

    dataframes = [pd.read_json(file_path) for file_path in file_paths]
    combined_dataframe = pd.concat(dataframes, ignore_index=True)
    return combined_dataframe

data_dir = 'data/'
df = read_json_files_as_dataframe(data_dir)

# %% [markdown]
# ### Overview

# %%
df.shape
# Out:
# (68867, 9)

# %%
def remove_duplicate_rows(df):
    """
    Remove rows from a DataFrame where all column values are exactly the same.

    Args:
        df (pd.DataFrame): The DataFrame to remove duplicate rows from.

    Returns:
        pd.DataFrame: The resulting DataFrame with duplicate rows removed.

    """
    num_duplicates = df.duplicated(keep=False, subset=df.columns.difference(['index'])).sum()
    df_without_duplicates = df.drop_duplicates(keep=False, subset=df.columns.difference(['index']))
    print(f"Removed {num_duplicates} duplicate rows")
    return df_without_duplicates

df = remove_duplicate_rows(df)
# Out:
# Removed 3082 duplicate rows

# %%
def remove_duplicate_rows_except_search(df):
    """
    Remove rows from a DataFrame where all column values are exactly the same except column search_term.

    Args:
        df (pd.DataFrame): The DataFrame to remove duplicate rows from.

    Returns:
        pd.DataFrame: The resulting DataFrame with duplicate rows removed.

    """
    num_duplicates = df.duplicated(keep=False, subset=df.columns.difference(['search_term'])).sum()
    df_without_duplicates = df.drop_duplicates(subset=df.columns.difference(['search_term']))
    print(f"Removed {num_duplicates} duplicate rows")
    return df_without_duplicates

df = remove_duplicate_rows_except_search(df)
# Out:
# Removed 43447 duplicate rows

# %%
df.shape
# Out:
# (40542, 9)

# %% [markdown]
# ### Categorias

# %%
df.nunique()
# Out:
# date               2
# aisle_name       661
# product_name    7705
# brand           1785
# price           2960
# package         1529
# store_name        19
# store_city         1
# search_term      342
# dtype: int64

# %% [markdown]
# ## Frutas

# %%
frutas_unique = df.query('aisle_name == "Frutas frescas"')['product_name'].nunique()
print(f"Temos {frutas_unique} e nomes únicos na categoria frutas frescas")
# Out:
# Temos 107 e nomes únicos na categoria frutas frescas

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")
frutas = df.query('aisle_name == "Frutas frescas"')
sns.displot(frutas, x="price", hue="store_name", kind="kde",multiple="stack");

# %% [markdown]
# ### Qual mercado as frutas podem estar mais baratas?

# %%
frutas.date.max().date()
# Out:
# datetime.date(2023, 8, 6)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))

# Plotar o gráfico de pontos com barras de erro
sns.pointplot(data=frutas, y='store_name', x='price', join=False, capsize=.3, markers='o', scale=1.1)

# Configurar o título e os rótulos dos eixos
plt.title('Média de preço por store_name')
plt.xlabel('Preço médio')
plt.ylabel('store_name')

# Exibir o gráfico
plt.show()

# %%
# Plotar o gráfico de barras com barras de erro
sns.barplot(data=frutas, y='store_name', x='price', ci=95)

# Configurar o título e os rótulos dos eixos
plt.title('Média de preço por store_name')
plt.xlabel('Preço médio')
plt.ylabel('store_name')

# Exibir o gráfico
plt.show()
# Out:
# C:\Users\Eric\AppData\Local\Temp\ipykernel_14600\831275815.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 95)` for the same effect.
#
#   sns.barplot(data=frutas, y='store_name', x='price', ci=95)

# %%
df.aisle_name.unique()
# Out:
# array(['Frutas frescas', 'Shampoo e condicionador',
#        'Produtos para finalização', 'Cremes e tratamentos corporais',
#        'Tratamentos capilares', 'Refrescos em pó',
#        'Iogurte, smoothies e kefir', 'Sucos e néctares',
#        'Misturas para assar', 'Gelatinas e pudim', 'Polpa de fruta',
#        'Óleo cozinha', 'Utensílios cozinha', 'Sabonetes',
#        'Petiscos para cães', 'Facial', 'Estômago e soros', 'Digestão',
#        'Antiácidos', 'Lábios', 'Cuidado labial', 'Colágenos',
#        'Banho e cuidados com o corpo Bebê',
#        'Mix de frutas secas e snacks variados a granel', 'Fresh Fruit',
#        'Shampoo & Conditioner', 'Styling Products',
#        'Body Creams & Treatments', 'Hair Treatments', 'Powdered',
#        'Fresh Juice & Nectar', 'Yogurt, Smoothies & Kefir',
#        'Baking Mixes & Gelatin', 'Gelatin & Custards', 'Frozen Juice',
#        'Oils', 'Soaps', 'Cookware', 'Treats',
# ...

# %%
df.columns
# Out:
# Index(['date', 'aisle_name', 'product_name', 'brand', 'price', 'package',
#        'store_name', 'store_city', 'search_term'],
#       dtype='object')

# %%
df.store_name.unique()
# Out:
# array(['BIG by Carrefour', 'Carrefour Hiper', 'Atacadão',
#        'Angeloni Supermercados', 'Hippo', 'Pague Menos', 'Droga Raia',
#        'Panvel', 'Drogaria Catarinense', 'Farmácia Preço Popular',
#        'AmoresPet', 'IMBUR Conceito Natural', 'Cobasi',
#        'Granado Pharmácias', "L'Occitane en Provence", 'Kalunga',
#        'The Body Shop', "L'Occitane au Brésil", 'Lindt'], dtype=object)

# %%
df.brand.unique()
# Out:
# array([None, 'Dabelle', 'Suave', ..., 'Lucretin', 'Kronel', 'Underskin'],
#       dtype=object)

# %%
df.aisle_name.unique()
# Out:
# array(['Frutas frescas', 'Shampoo e condicionador',
#        'Produtos para finalização', 'Cremes e tratamentos corporais',
#        'Tratamentos capilares', 'Refrescos em pó',
#        'Iogurte, smoothies e kefir', 'Sucos e néctares',
#        'Misturas para assar', 'Gelatinas e pudim', 'Polpa de fruta',
#        'Óleo cozinha', 'Utensílios cozinha', 'Sabonetes',
#        'Petiscos para cães', 'Facial', 'Estômago e soros', 'Digestão',
#        'Antiácidos', 'Lábios', 'Cuidado labial', 'Colágenos',
#        'Banho e cuidados com o corpo Bebê',
#        'Mix de frutas secas e snacks variados a granel', 'Fresh Fruit',
#        'Shampoo & Conditioner', 'Styling Products',
#        'Body Creams & Treatments', 'Hair Treatments', 'Powdered',
#        'Fresh Juice & Nectar', 'Yogurt, Smoothies & Kefir',
#        'Baking Mixes & Gelatin', 'Gelatin & Custards', 'Frozen Juice',
#        'Oils', 'Soaps', 'Cookware', 'Treats',
# ...

# %% [markdown]
# ## Leite

# %%
leites= df.query("aisle_name =='Leite' or aisle_name =='Leites'")
leites = leites.query('package=="1l" or package=="Caixa 1l"')
leites
# Out:
#             date aisle_name                                  product_name  \
# 8012  2023-08-06      Leite                 Leite UHT integral 3% gordura
# 8040  2023-08-06      Leite                 Leite UHT integral 3% gordura
# 17623 2023-08-06      Leite                            Leite UHT integral
# 17647 2023-08-06      Leite                            Leite UHT integral
# 33724 2023-08-06      Leite                      Leite integral UHT Ninho
# 33738 2023-08-06      Leite                      Leite integral UHT Ninho
# 33751 2023-08-06      Leite                      Leite integral UHT Ninho
# 33760 2023-08-06      Leite                      Leite integral UHT Ninho
# 33770 2023-08-06      Leite                      Leite integral UHT Ninho
# 34105 2023-08-06      Leite                           Leite desnatado UHT
# 34231 2023-08-06      Leite                            Leite UHT integral
# 34248 2023-08-06      Leite                            Leite integral UHT
# ...

# %%
sns.pointplot(data=leites, y='store_name', x='price', orient='h', join=False, capsize=.3, errorbar=('ci', 95), markers='o', scale=1.1);

# %% [markdown]
# ### Qual mercado tem o leite mais barato?

# %%
leite= df.query("aisle_name =='Leite' & search_term == 'Leite'")
leite_1l = leite.query('package=="1l" or package=="Caixa 1l"')
leite_top_10 = leite_1l.sort_values(by='price', ascending=True).head(10)
leite_top_10
# Out:
#             date aisle_name                    product_name        brand  \
# 35266 2023-08-06      Leite             Leite UHT desnatado       Italac
# 35367 2023-08-06      Leite  Leite semidesnatado UHT tipo A     Parmalat
# 35295 2023-08-06      Leite             Leite UHT desnatado       Italac
# 35327 2023-08-06      Leite              Leite UHT integral        Elegê
# 35328 2023-08-06      Leite              Leite UHT integral        Tirol
# 35332 2023-08-06      Leite  Leite semidesnatado UHT tipo A     Parmalat
# 35262 2023-08-06      Leite      Leite UHT desnatado Molico       Nestlé
# 35292 2023-08-06      Leite      Leite UHT desnatado Molico       Nestlé
# 35330 2023-08-06      Leite             Leite semidesnatado  Piracanjuba
# 35298 2023-08-06      Leite             Leite UHT desnatado  Piracanjuba
#
#        price   package              store_name store_city search_term
# 35266   4.69  Caixa 1l        BIG by Carrefour        FLN       Leite
# ...

# %% [markdown]
# ### Em média qual o preço do leite por marca?

# %%
leite_1l.groupby('brand')['price'].mean().round(2).sort_values().to_frame()
# Out:
#                     price
# brand
# Italac               4.69
# Elegê                4.79
# Parmalat             4.79
# Piracanjuba          5.67
# Nestlé               6.33
# Tirol                6.38
# Fazenda Bela Vista   8.98

# %% [markdown]
# ### Em média, qual mercado sai o leite é mais barato?

# %%
leite_1l.groupby('store_name')['price'].mean().round(2).sort_values().to_frame()
# Out:
#                         price
# store_name
# Atacadão                 4.69
# Angeloni Supermercados   5.25
# BIG by Carrefour         5.57
# Carrefour Hiper          5.57
# Hippo                    7.44
